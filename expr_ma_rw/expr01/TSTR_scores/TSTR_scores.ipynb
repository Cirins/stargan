# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd drive/MyDrive/ST/stargan
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/ST/stargan

# %% [markdown]
# # Configuration

# %%
import pickle
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import accuracy_score, f1_score
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from torch.optim.lr_scheduler import LambdaLR
import torch.optim as optim
import os
import csv
import random
import copy

seed = 2710
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

# %%
config = {
    'realworld': {
        'dataset_name': 'realworld',
        'num_df_domains': 10,
        'num_dp_domains': 5,
        'num_classes': 4,
        'class_names': ['WAL', 'RUN', 'CLD', 'CLU'],
        'num_timesteps': 128,
        'num_channels': 3,
        'num_classes': 4,
    },
    'cwru': {
        'dataset_name': 'cwru_256_3ch_5cl',
        'num_df_domains': 4,
        'num_dp_domains': 4,
        'num_classes': 5,
        'class_names': ['IR', 'Ball', 'OR_centred', 'OR_orthogonal', 'OR_opposite'],
        'num_timesteps': 256,
        'num_channels': 3,
        'num_classes': 5,
    },
    'realworld_mobiact': {
        'dataset_name': 'realworld_mobiact',
        'num_df_domains': 15,
        'num_dp_domains': 61,
        'num_classes': 4,
        'class_names': ['WAL', 'RUN', 'CLD', 'CLU'],
        'num_timesteps': 128,
        'num_channels': 3,
        'num_classes': 4,
    },
    'mobiact_realworld': {
        'dataset_name': 'mobiact_realworld',
        'num_df_domains': 61,
        'num_dp_domains': 15,
        'num_classes': 4,
        'class_names': ['WAL', 'RUN', 'CLD', 'CLU'],
        'num_timesteps': 128,
        'num_channels': 3,
        'num_classes': 4,
    }
}

syn_name = 'marw01'
num_epochs = 100
num_runs = 10

# %%
def get_data(dataset, domains_set, src_class, domain=None, rot=False):
    # Load configurations
    dataset_name = config[dataset]['dataset_name']
    class_idx = config[dataset]['class_names'].index(src_class)
    num_df_domains = config[dataset]['num_df_domains']

    if rot:
        dataset_name += '_rot'

    try:
        with open(f'data/{dataset_name}.pkl', 'rb') as f:
            x, y, k = pickle.load(f)
        with open(f'data/{dataset_name}_fs.pkl', 'rb') as f:
            fs = pickle.load(f)
    except FileNotFoundError:
        raise FileNotFoundError(f"Dataset files for {dataset} not found.")


    if domains_set == 'df':
        mask = (y != class_idx) & (k < num_df_domains)
    elif domains_set == 'dp':
        mask = (y != class_idx) & (k >= num_df_domains) & (fs == 0)
    elif domains_set == 'dpfs':
        mask = (y != class_idx) & (k >= num_df_domains) & (fs == 1)
    else:
        raise ValueError(f"Invalid domains set: {domains_set}")

    # Apply initial mask
    x, y, k = x[mask], y[mask], k[mask]

    # Additional domain filtering if specified
    if domain is not None:
        domain_mask = (k == domain)
        x, y, k = x[domain_mask], y[domain_mask], k[domain_mask]

    assert len(x) > 0, f"No data found"
    assert len(x) == len(y) == len(k), f"Data length mismatch"

    return x, y, k



def get_syn_data(dataset, syn_name, src_class, domain=None, fs=False):
    # Load configurations
    class_names = config[dataset]['class_names']

    try:
        with open(f'data/{dataset}_{syn_name}.pkl', 'rb') as f:
            x, y, k = pickle.load(f)
    except FileNotFoundError:
        raise FileNotFoundError(f"Dataset files for {dataset} not found.")

    with open(f'data/{dataset}_{syn_name}_fs.pkl', 'rb') as f:
        fs = pickle.load(f)

    x, y, k = x[fs == 0], y[fs == 0], k[fs == 0]

    if domain is not None:
        domain_mask = (k == domain)
        x, y, k = x[domain_mask], y[domain_mask], k[domain_mask]

    assert len(x) > 0, f"No data found"
    assert len(x) == len(y) == len(k), f"Data length mismatch"

    return x, y, k



class TSTRClassifier(nn.Module):
    def __init__(self, num_timesteps=128, num_channels=3, num_classes=5):
        super(TSTRClassifier, self).__init__()

        self.conv1 = nn.Conv1d(num_channels, 16, kernel_size=5, stride=1, padding=2)
        self.bn1 = nn.BatchNorm1d(16)
        self.conv2 = nn.Conv1d(16, 32, kernel_size=5, stride=1, padding=2)
        self.bn2 = nn.BatchNorm1d(32)
        self.conv3 = nn.Conv1d(32, 64, kernel_size=5, stride=1, padding=2)
        self.bn3 = nn.BatchNorm1d(64)
        self.conv4 = nn.Conv1d(64, 128, kernel_size=5, stride=1, padding=2)
        self.bn4 = nn.BatchNorm1d(128)
        self.pool = nn.MaxPool1d(kernel_size=2, stride=2)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.25)

        self.fc_shared = nn.Linear(num_timesteps * 8, 100)

        self.fc_class = nn.Linear(100, num_classes)

    def forward(self, x):
        x = self.pool(self.relu(self.bn1(self.conv1(x))))
        x = self.pool(self.relu(self.bn2(self.conv2(x))))
        x = self.pool(self.relu(self.bn3(self.conv3(x))))
        x = self.pool(self.relu(self.bn4(self.conv4(x))))
        x = x.view(x.size(0), -1)  # Flatten
        x = self.dropout(x)
        x = self.relu(self.fc_shared(x))

        # Final output for class prediction
        class_outputs = self.fc_class(x)
        return class_outputs



def remap_labels(y):
    label_map = {clss: i for i, clss in enumerate(np.unique(y))}
    return np.array([label_map[clss] for clss in y])



def get_dataloader(x, y, shuffle=False):
    x = torch.tensor(x, dtype=torch.float32)
    y = remap_labels(y)
    y = torch.tensor(y, dtype=torch.long)

    # Determine dataset size and batch size
    dataset_size = len(x)
    if dataset_size <= 100:
        batch_size = dataset_size
    elif dataset_size <= 1000:
        batch_size = 16
    elif dataset_size <= 5000:
        batch_size = 32
    else:
        batch_size = 64

    dataset = TensorDataset(x, y)
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=shuffle)

    return loader


def random_rotation_matrix():
    """Generate a random rotation matrix from a predefined set of quaternions."""
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Randomly generate a quaternion
    q = np.random.rand(4)

    # Convert quaternion to rotation matrix
    q = torch.tensor(q, device=device, dtype=torch.float32)
    q = q / torch.norm(q)  # Normalize quaternion
    q0, q1, q2, q3 = q

    R = torch.tensor([
        [1 - 2*q2**2 - 2*q3**2, 2*q1*q2 - 2*q3*q0, 2*q1*q3 + 2*q2*q0],
        [2*q1*q2 + 2*q3*q0, 1 - 2*q1**2 - 2*q3**2, 2*q2*q3 - 2*q1*q0],
        [2*q1*q3 - 2*q2*q0, 2*q2*q3 + 2*q1*q0, 1 - 2*q1**2 - 2*q2**2]
    ], device=device, dtype=torch.float32)

    return R, q


def augment_batch(x_real):
    """Apply random rotation to the batch of real time series."""
    min_val, max_val = -19.61, 19.61
    x_real = x_real * (max_val - min_val) + min_val  # De-normalize
    R, q = random_rotation_matrix()
    x_real = torch.matmul(R, x_real)  # Apply rotation
    x_real = (x_real - min_val) / (max_val - min_val)  # Re-normalize
    return x_real, q



def evaluate_model(model, test_loader):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval()

    loss_fn = nn.CrossEntropyLoss()

    total_loss = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            outputs = model(x_batch)
            loss = loss_fn(outputs, y_batch)
            total_loss += loss.item()

            _, predicted_labels = torch.max(outputs, 1)
            all_preds.extend(predicted_labels.detach().cpu().numpy())
            all_labels.extend(y_batch.detach().cpu().numpy())

    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)
    accuracy = accuracy_score(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds, average='weighted')
    total_loss /= len(test_loader)

    return accuracy, total_loss, f1



def train_model(model, train_loader, val_loader, optimizer, num_epochs=100, augment=False):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    loss_fn = nn.CrossEntropyLoss()

    loss_train = []
    loss_val = []
    accuracy_val = []
    best_model_state = None
    best_loss = np.inf
    best_accuracy = 0
    best_f1 = 0

    # Set up linear learning rate decay
    lambda_lr = lambda epoch: 1 - epoch / num_epochs
    scheduler = LambdaLR(optimizer, lr_lambda=lambda_lr)

    for epoch in range(num_epochs):
        model.train()
        total_loss = 0
        for x_batch, y_batch in train_loader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            if augment:
                x_batch, _ = augment_batch(x_batch)
            optimizer.zero_grad()
            outputs = model(x_batch)
            loss = loss_fn(outputs, y_batch)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        total_loss /= len(train_loader)
        loss_train.append(total_loss)

        # Update learning rate
        scheduler.step()

        val_accuracy, val_loss, val_f1 = evaluate_model(model, val_loader)
        if val_loss < best_loss:
            best_epoch = epoch
            best_accuracy = val_accuracy
            best_f1 = val_f1
            best_loss = val_loss
            best_model_state = model.state_dict().copy()

        loss_val.append(val_loss)
        accuracy_val.append(val_accuracy)

        current_lr = scheduler.get_last_lr()[0]
        if (epoch+1) % 10 == 0:
            print(f"\tEpoch {epoch + 1}/{num_epochs} - Train loss: {total_loss:.4f} - Val accuracy: {val_accuracy:.4f} - Val loss: {val_loss:.4f} - Val F1: {val_f1:.4f} - LR: {current_lr:.2e}")

    print(f"\tBest epoch: {best_epoch + 1} - Best val accuracy: {best_accuracy:.4f} - Best val loss: {best_loss:.4f} - Best val F1: {best_f1:.4f}\n")

    # Load best model state
    model.load_state_dict(best_model_state)

    return model



def train_and_test(x_train, y_train, x_test, y_test, dataset, num_epochs=100, augment=False):
    assert np.array_equal(np.unique(y_train), np.unique(y_test)), "Training and test labels do not match"

    x_tr, x_val, y_tr, y_val = train_test_split(x_train, y_train, test_size=0.2, stratify=y_train, shuffle=True, random_state=seed)

    train_loader = get_dataloader(x_tr, y_tr, shuffle=True)
    val_loader = get_dataloader(x_val, y_val)
    test_loader = get_dataloader(x_test, y_test)

    model = TSTRClassifier(num_timesteps=config[dataset]['num_timesteps'],
                           num_channels=config[dataset]['num_channels'],
                           num_classes=config[dataset]['num_classes']-1)
    initial_lr = 0.0001
    optimizer = optim.Adam(model.parameters(), lr=initial_lr)

    trained_model = train_model(model, train_loader, val_loader, optimizer, num_epochs, augment)

    test_accuracy, test_loss, test_f1 = evaluate_model(trained_model, test_loader)

    return test_accuracy, test_loss, test_f1



def train_only(x_train, y_train, dataset, num_epochs=100, augment=False):

    x_tr, x_val, y_tr, y_val = train_test_split(x_train, y_train, test_size=0.2, stratify=y_train, shuffle=True, random_state=seed)

    train_loader = get_dataloader(x_tr, y_tr, shuffle=True)
    val_loader = get_dataloader(x_val, y_val)

    model = TSTRClassifier(num_timesteps=config[dataset]['num_timesteps'],
                           num_channels=config[dataset]['num_channels'],
                           num_classes=config[dataset]['num_classes']-1)
    initial_lr = 0.0001
    optimizer = optim.Adam(model.parameters(), lr=initial_lr)

    trained_model = train_model(model, train_loader, val_loader, optimizer, num_epochs, augment=augment)

    return trained_model



def train_classifier_cv(x_train, y_train, dataset, num_epochs=100):
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)

    accs = []
    losses = []
    f1s = []

    for train_index, test_index in skf.split(x_train, y_train):
        x_train_fold, x_test_fold = x_train[train_index], x_train[test_index]
        y_train_fold, y_test_fold = y_train[train_index], y_train[test_index]

        acc, loss, f1 = train_and_test(x_train_fold, y_train_fold, x_test_fold, y_test_fold, dataset, num_epochs)
        accs.append(acc)
        losses.append(loss)
        f1s.append(f1)
    return np.mean(accs), np.mean(losses), np.mean(f1s)



def fine_tune(model, x_train, y_train, num_epochs=100):
    # Freeze feature extraction layers
    for name, param in model.named_parameters():
        if 'conv' in name or 'bn' in name:
            param.requires_grad = False

    x_tr, x_val, y_tr, y_val = train_test_split(x_train, y_train, test_size=0.2, stratify=y_train, shuffle=True, random_state=seed)

    train_loader = get_dataloader(x_tr, y_tr, shuffle=True)
    val_loader = get_dataloader(x_val, y_val)

    initial_lr = 0.00001
    optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=initial_lr)

    trained_model = train_model(model, train_loader, val_loader, optimizer, num_epochs)

    return trained_model



def save_scores(source, domain, accuracy, loss, f1, name, dataset):
    results_dir = 'results'
    # Ensure the directory exists
    os.makedirs(results_dir, exist_ok=True)
    # Path to the CSV file
    file_path = os.path.join(results_dir, f'{dataset}_{name}.csv')
    # Check if the file exists
    file_exists = os.path.exists(file_path)

    # Open the file in append mode if it exists, or write mode if it doesn't
    with open(file_path, mode='a' if file_exists else 'w', newline='') as file:
        writer = csv.writer(file)
        # If the file does not exist, write the header
        if not file_exists:
            writer.writerow(['source', 'domain', 'accuracy', 'loss', 'f1'])
        # Write the data rows
        writer.writerow([source, domain, accuracy, loss, f1])

# %% [markdown]
# # TSTR

# %%
def compute_TSTR_Dp(dataset):
    accs = []
    f1s = []

    for src_class in config[dataset]['class_names']:
        if src_class != 'WAL':
            continue

        print(f"Source class: {src_class}\n")

        for domain in range(config[dataset]['num_df_domains'], config[dataset]['num_df_domains'] + config[dataset]['num_dp_domains']):
            print(f"Domain: {domain}")

            # Load Dp data
            x_dp_dom, y_dp_dom, k_dp_dom = get_data(dataset, 'dp', src_class, domain)
            print(f'x_dp_dom.shape: {x_dp_dom.shape} | np.unique(y_dp_dom): {np.unique(y_dp_dom)}\n')

            # Train and evaluate via cross-validation on Dp data
            print('Training and evaluating on Dp data via cross-validation...')
            acc, loss, f1 = train_classifier_cv(x_dp_dom, y_dp_dom, dataset, num_epochs=num_epochs)
            save_scores(src_class, domain, acc, loss, f1, 'Dp', dataset)
            accs.append(acc)
            f1s.append(f1)
            print(f'Source class: {src_class} | Domain: {domain} | Accuracy: {acc:.4f} | Loss: {loss:.4f} | F1: {f1:.4f}\n')

    print(f"Mean accuracy: {np.mean(accs):.4f} +- {np.std(accs):.4f}")
    print(f"Mean F1: {np.mean(f1s):.4f} +- {np.std(f1s):.4f}\n")



compute_TSTR_Dp('mobiact_realworld')
# Out:
# Source class: WAL
#
# Domain: 61
# x_dp_dom.shape: (623, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Training and evaluating on Dp data via cross-validation...
# 	Epoch 10/100 - Train loss: 0.0364 - Val accuracy: 0.9900 - Val loss: 0.0344 - Val F1: 0.9900 - LR: 9.00e-05
# 	Epoch 20/100 - Train loss: 0.0148 - Val accuracy: 0.9900 - Val loss: 0.0165 - Val F1: 0.9900 - LR: 8.00e-05
# 	Epoch 30/100 - Train loss: 0.0034 - Val accuracy: 1.0000 - Val loss: 0.0128 - Val F1: 1.0000 - LR: 7.00e-05
# 	Epoch 40/100 - Train loss: 0.0019 - Val accuracy: 1.0000 - Val loss: 0.0063 - Val F1: 1.0000 - LR: 6.00e-05
# 	Epoch 50/100 - Train loss: 0.0012 - Val accuracy: 1.0000 - Val loss: 0.0048 - Val F1: 1.0000 - LR: 5.00e-05
# 	Epoch 60/100 - Train loss: 0.0021 - Val accuracy: 1.0000 - Val loss: 0.0042 - Val F1: 1.0000 - LR: 4.00e-05
# 	Epoch 70/100 - Train loss: 0.0016 - Val accuracy: 1.0000 - Val loss: 0.0045 - Val F1: 1.0000 - LR: 3.00e-05
# 	Epoch 80/100 - Train loss: 0.0007 - Val accuracy: 1.0000 - Val loss: 0.0037 - Val F1: 1.0000 - LR: 2.00e-05
# 	Epoch 90/100 - Train loss: 0.0006 - Val accuracy: 1.0000 - Val loss: 0.0035 - Val F1: 1.0000 - LR: 1.00e-05
# 	Epoch 100/100 - Train loss: 0.0005 - Val accuracy: 1.0000 - Val loss: 0.0035 - Val F1: 1.0000 - LR: 0.00e+00
# 	Best epoch: 100 - Best val accuracy: 1.0000 - Best val loss: 0.0035 - Best val F1: 1.0000
#
# 	Epoch 10/100 - Train loss: 0.0375 - Val accuracy: 0.9900 - Val loss: 0.0444 - Val F1: 0.9900 - LR: 9.00e-05
# 	Epoch 20/100 - Train loss: 0.0131 - Val accuracy: 0.9900 - Val loss: 0.0239 - Val F1: 0.9900 - LR: 8.00e-05
# 	Epoch 30/100 - Train loss: 0.0059 - Val accuracy: 1.0000 - Val loss: 0.0105 - Val F1: 1.0000 - LR: 7.00e-05
# 	Epoch 40/100 - Train loss: 0.0030 - Val accuracy: 1.0000 - Val loss: 0.0071 - Val F1: 1.0000 - LR: 6.00e-05
# 	Epoch 50/100 - Train loss: 0.0010 - Val accuracy: 1.0000 - Val loss: 0.0050 - Val F1: 1.0000 - LR: 5.00e-05
# 	Epoch 60/100 - Train loss: 0.0008 - Val accuracy: 1.0000 - Val loss: 0.0051 - Val F1: 1.0000 - LR: 4.00e-05
# 	Epoch 70/100 - Train loss: 0.0006 - Val accuracy: 1.0000 - Val loss: 0.0038 - Val F1: 1.0000 - LR: 3.00e-05
# 	Epoch 80/100 - Train loss: 0.0005 - Val accuracy: 1.0000 - Val loss: 0.0037 - Val F1: 1.0000 - LR: 2.00e-05
# 	Epoch 90/100 - Train loss: 0.0008 - Val accuracy: 1.0000 - Val loss: 0.0030 - Val F1: 1.0000 - LR: 1.00e-05
# 	Epoch 100/100 - Train loss: 0.0037 - Val accuracy: 1.0000 - Val loss: 0.0030 - Val F1: 1.0000 - LR: 0.00e+00
# 	Best epoch: 90 - Best val accuracy: 1.0000 - Best val loss: 0.0030 - Best val F1: 1.0000
#
# 	Epoch 10/100 - Train loss: 0.0413 - Val accuracy: 0.9800 - Val loss: 0.0371 - Val F1: 0.9800 - LR: 9.00e-05
# 	Epoch 20/100 - Train loss: 0.0126 - Val accuracy: 0.9900 - Val loss: 0.0229 - Val F1: 0.9900 - LR: 8.00e-05
# 	Epoch 30/100 - Train loss: 0.0110 - Val accuracy: 0.9900 - Val loss: 0.0219 - Val F1: 0.9900 - LR: 7.00e-05
# 	Epoch 40/100 - Train loss: 0.0054 - Val accuracy: 0.9900 - Val loss: 0.0147 - Val F1: 0.9900 - LR: 6.00e-05
# 	Epoch 50/100 - Train loss: 0.
- LR: 2.00e-05
# 	Epoch 90/100 - Train loss: 0.0025 - Val accuracy: 0.9785 - Val loss: 0.0815 - Val F1: 0.9787 - LR: 1.00e-05
# 	Epoch 100/100 - Train loss: 0.0025 - Val accuracy: 0.9677 - Val loss: 0.0815 - Val F1: 0.9679 - LR: 0.00e+00
# 	Best epoch: 44 - Best val accuracy: 0.9677 - Best val loss: 0.0730 - Best val F1: 0.9679
#
# Source class: WAL | Domain: 75 | Accuracy: 0.9845 | Loss: 0.0493 | F1: 0.9845
#
# Mean accuracy: 0.9890 +- 0.0063
# Mean F1: 0.9890 +- 0.0063

# %%
def compute_TSTR_Dpc(dataset):

    raise NotImplementedError



# compute_TSTR_Dpc('mobiact_realworld')

# %%
def compute_TSTR_Df(dataset):
    accs = []
    f1s = []

    for i in range(num_runs):

        accs_run = []
        f1s_run = []

        for src_class in config[dataset]['class_names']:
            if src_class != 'WAL':
                continue

            print(f"Source class: {src_class}\n")

            # Load Df data
            x_df, y_df, k_df = get_data(dataset, 'df', src_class)
            print(f'x_df.shape: {x_df.shape} | np.unique(y_df): {np.unique(y_df)}\n')

            # Train on Df data
            print('Training on Df data...')
            df_model = train_only(x_df, y_df, dataset, num_epochs=num_epochs)

            for domain in range(config[dataset]['num_df_domains'], config[dataset]['num_df_domains'] + config[dataset]['num_dp_domains']):
                print(f"Domain: {domain}")

                # Load Dp data
                x_dp_dom, y_dp_dom, k_dp_dom = get_data(dataset, 'dp', src_class, domain)
                print(f'x_dp_dom.shape: {x_dp_dom.shape} | np.unique(y_dp_dom): {np.unique(y_dp_dom)}\n')

                # Evaluate on Dp data
                acc, loss, f1 = evaluate_model(df_model, get_dataloader(x_dp_dom, y_dp_dom))
                save_scores(src_class, domain, acc, loss, f1, 'Df', dataset)
                accs_run.append(acc)
                f1s_run.append(f1)
                print(f'Source class: {src_class} | Domain: {domain} | Accuracy: {acc:.4f} | Loss: {loss:.4f} | F1: {f1:.4f}\n')

        print(f"Mean accuracy for run {i}: {np.mean(accs_run):.4f}")
        print(f"Mean F1 for run {i}: {np.mean(f1s_run):.4f}\n")
        accs.append(np.mean(accs_run))
        f1s.append(np.mean(f1s_run))

    print(f"Mean accuracy over {num_runs} runs: {np.mean(accs):.4f} +- {np.std(accs):.4f}")
    print(f"Mean F1 over {num_runs} runs: {np.mean(f1s):.4f} +- {np.std(f1s):.4f}\n")




compute_TSTR_Df('mobiact_realworld')
# Out:
# Source class: WAL
#
# x_df.shape: (3729, 3, 128) | np.unique(y_df): [1 2 3]
#
# Training on Df data...
# 	Epoch 10/100 - Train loss: 0.0466 - Val accuracy: 0.9866 - Val loss: 0.0423 - Val F1: 0.9866 - LR: 9.00e-05
# 	Epoch 20/100 - Train loss: 0.0108 - Val accuracy: 0.9893 - Val loss: 0.0299 - Val F1: 0.9893 - LR: 8.00e-05
# 	Epoch 30/100 - Train loss: 0.0101 - Val accuracy: 0.9906 - Val loss: 0.0206 - Val F1: 0.9906 - LR: 7.00e-05
# 	Epoch 40/100 - Train loss: 0.0018 - Val accuracy: 0.9946 - Val loss: 0.0161 - Val F1: 0.9946 - LR: 6.00e-05
# 	Epoch 50/100 - Train loss: 0.0030 - Val accuracy: 0.9946 - Val loss: 0.0181 - Val F1: 0.9946 - LR: 5.00e-05
# 	Epoch 60/100 - Train loss: 0.0010 - Val accuracy: 0.9946 - Val loss: 0.0165 - Val F1: 0.9946 - LR: 4.00e-05
# 	Epoch 70/100 - Train loss: 0.0036 - Val accuracy: 0.9946 - Val loss: 0.0157 - Val F1: 0.9947 - LR: 3.00e-05
# 	Epoch 80/100 - Train loss: 0.0010 - Val accuracy: 0.9946 - Val loss: 0.0196 - Val F1: 0.9946 - LR: 2.00e-05
# 	Epoch 90/100 - Train loss: 0.0006 - Val accuracy: 0.9946 - Val loss: 0.0195 - Val F1: 0.9946 - LR: 1.00e-05
# 	Epoch 100/100 - Train loss: 0.0004 - Val accuracy: 0.9960 - Val loss: 0.0162 - Val F1: 0.9960 - LR: 0.00e+00
# 	Best epoch: 72 - Best val accuracy: 0.9973 - Best val loss: 0.0105 - Best val F1: 0.9973
#
# Domain: 61
# x_dp_dom.shape: (623, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 61 | Accuracy: 0.6148 | Loss: 1.5297 | F1: 0.5442
#
# Domain: 62
# x_dp_dom.shape: (558, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 62 | Accuracy: 0.8495 | Loss: 0.4973 | F1: 0.8432
#
# Domain: 63
# x_dp_dom.shape: (610, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 63 | Accuracy: 0.6016 | Loss: 1.4645 | F1: 0.5449
#
# Domain: 64
# x_dp_dom.shape: (257, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 64 | Accuracy: 0.7354 | Loss: 1.4632 | F1: 0.6720
#
# Domain: 65
# x_dp_dom.shape: (586, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 65 | Accuracy: 0.7423 | Loss: 0.7892 | F1: 0.6927
#
# Domain: 66
# x_dp_dom.shape: (563, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 66 | Accuracy: 0.7052 | Loss: 1.2769 | F1: 0.6283
#
# Domain: 67
# x_dp_dom.shape: (349, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 67 | Accuracy: 0.8424 | Loss: 0.5559 | F1: 0.7881
#
# Domain: 68
# x_dp_dom.shape: (638, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 68 | Accuracy: 0.8903 | Loss: 0.3704 | F1: 0.8811
#
# Domain: 69
# x_dp_dom.shape: (572, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 69 | Accuracy: 0.7710 | Loss: 0.8263 | F1: 0.7336
#
# Domain: 70
# x_dp_dom.shape: (532, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 70 | Accuracy: 0
#
# Domain: 63
# x_dp_dom.shape: (610, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 63 | Accuracy: 0.7377 | Loss: 0.7817 | F1: 0.6842
#
# Domain: 64
# x_dp_dom.shape: (257, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 64 | Accuracy: 0.7121 | Loss: 1.1714 | F1: 0.6491
#
# Domain: 65
# x_dp_dom.shape: (586, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 65 | Accuracy: 0.7048 | Loss: 0.9794 | F1: 0.6068
#
# Domain: 66
# x_dp_dom.shape: (563, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 66 | Accuracy: 0.7052 | Loss: 0.9931 | F1: 0.6151
#
# Domain: 67
# x_dp_dom.shape: (349, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 67 | Accuracy: 0.8424 | Loss: 0.6015 | F1: 0.7881
#
# Domain: 68
# x_dp_dom.shape: (638, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 68 | Accuracy: 0.8809 | Loss: 0.3025 | F1: 0.8682
#
# Domain: 69
# x_dp_dom.shape: (572, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 69 | Accuracy: 0.7378 | Loss: 0.7480 | F1: 0.6805
#
# Domain: 70
# x_dp_dom.shape: (532, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 70 | Accuracy: 0.7613 | Loss: 1.2236 | F1: 0.7025
#
# Domain: 71
# x_dp_dom.shape: (612, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 71 | Accuracy: 0.7337 | Loss: 0.8789 | F1: 0.6566
#
# Domain: 72
# x_dp_dom.shape: (581, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 72 | Accuracy: 0.7246 | Loss: 0.8600 | F1: 0.6449
#
# Domain: 73
# x_dp_dom.shape: (577, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 73 | Accuracy: 0.7522 | Loss: 0.7751 | F1: 0.6725
#
# Domain: 74
# x_dp_dom.shape: (319, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 74 | Accuracy: 0.8934 | Loss: 0.5413 | F1: 0.8604
#
# Domain: 75
# x_dp_dom.shape: (581, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 75 | Accuracy: 0.7263 | Loss: 0.8704 | F1: 0.6592
#
# Mean accuracy for run 9: 0.7546
# Mean F1 for run 9: 0.6945
#
# Mean accuracy over 10 runs: 0.7651 +- 0.0764
# Mean F1 over 10 runs: 0.7376 +- 0.0896

# %%
def compute_TSTR_Df_aug(dataset):
    accs = []
    f1s = []

    for i in range(num_runs):

        accs_run = []
        f1s_run = []

        for src_class in config[dataset]['class_names']:
            if src_class != 'WAL':
                continue

            print(f"Source class: {src_class}\n")

            # Load Df data
            x_df, y_df, k_df = get_data(dataset, 'df', src_class)
            print(f'x_df.shape: {x_df.shape} | np.unique(y_df): {np.unique(y_df)}\n')

            # Train on Df data
            print('Training on Df data...')
            df_model = train_only(x_df, y_df, dataset, num_epochs=num_epochs, augment=True)

            for domain in range(config[dataset]['num_df_domains'], config[dataset]['num_df_domains'] + config[dataset]['num_dp_domains']):
                print(f"Domain: {domain}")

                # Load Dp data
                x_dp_dom, y_dp_dom, k_dp_dom = get_data(dataset, 'dp', src_class, domain)
                print(f'x_dp_dom.shape: {x_dp_dom.shape} | np.unique(y_dp_dom): {np.unique(y_dp_dom)}\n')

                # Evaluate on Dp data
                acc, loss, f1 = evaluate_model(df_model, get_dataloader(x_dp_dom, y_dp_dom))
                save_scores(src_class, domain, acc, loss, f1, 'Df_aug', dataset)
                accs_run.append(acc)
                f1s_run.append(f1)
                print(f'Source class: {src_class} | Domain: {domain} | Accuracy: {acc:.4f} | Loss: {loss:.4f} | F1: {f1:.4f}\n')

        print(f"Mean accuracy for run {i}: {np.mean(accs_run):.4f}")
        print(f"Mean F1 for run {i}: {np.mean(f1s_run):.4f}\n")
        accs.append(np.mean(accs_run))
        f1s.append(np.mean(f1s_run))

    print(f"Mean accuracy over {num_runs} runs: {np.mean(accs):.4f} +- {np.std(accs):.4f}")
    print(f"Mean F1 over {num_runs} runs: {np.mean(f1s):.4f} +- {np.std(f1s):.4f}\n")




compute_TSTR_Df_aug('mobiact_realworld')
# Out:
# Source class: WAL
#
# x_df.shape: (3729, 3, 128) | np.unique(y_df): [1 2 3]
#
# Training on Df data...
# 	Epoch 10/100 - Train loss: 0.1818 - Val accuracy: 0.7761 - Val loss: 0.4812 - Val F1: 0.7404 - LR: 9.00e-05
# 	Epoch 20/100 - Train loss: 0.1118 - Val accuracy: 0.8271 - Val loss: 0.3831 - Val F1: 0.8265 - LR: 8.00e-05
# 	Epoch 30/100 - Train loss: 0.0870 - Val accuracy: 0.8633 - Val loss: 0.3321 - Val F1: 0.8592 - LR: 7.00e-05
# 	Epoch 40/100 - Train loss: 0.0610 - Val accuracy: 0.8646 - Val loss: 0.3136 - Val F1: 0.8633 - LR: 6.00e-05
# 	Epoch 50/100 - Train loss: 0.0559 - Val accuracy: 0.8660 - Val loss: 0.3085 - Val F1: 0.8657 - LR: 5.00e-05
# 	Epoch 60/100 - Train loss: 0.0419 - Val accuracy: 0.8874 - Val loss: 0.2790 - Val F1: 0.8852 - LR: 4.00e-05
# 	Epoch 70/100 - Train loss: 0.0342 - Val accuracy: 0.8901 - Val loss: 0.2665 - Val F1: 0.8896 - LR: 3.00e-05
# 	Epoch 80/100 - Train loss: 0.0273 - Val accuracy: 0.8727 - Val loss: 0.2841 - Val F1: 0.8741 - LR: 2.00e-05
# 	Epoch 90/100 - Train loss: 0.0257 - Val accuracy: 0.9142 - Val loss: 0.2244 - Val F1: 0.9139 - LR: 1.00e-05
# 	Epoch 100/100 - Train loss: 0.0237 - Val accuracy: 0.9008 - Val loss: 0.2360 - Val F1: 0.9003 - LR: 0.00e+00
# 	Best epoch: 98 - Best val accuracy: 0.9182 - Best val loss: 0.2166 - Best val F1: 0.9179
#
# Domain: 61
# x_dp_dom.shape: (623, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 61 | Accuracy: 0
- LR: 8.00e-05
# 	Epoch 30/100 - Train loss: 0.0687 - Val accuracy: 0.8686 - Val loss: 0.3240 - Val F1: 0.8684 - LR: 7.00e-05
# 	Epoch 40/100 - Train loss: 0.0540 - Val accuracy: 0.8794 - Val loss: 0.3035 - Val F1: 0.8797 - LR: 6.00e-05
# 	Epoch 50/100 - Train loss: 0.0469 - Val accuracy: 0.8820 - Val loss: 0.2811 - Val F1: 0.8805 - LR: 5.00e-05
# 	Epoch 60/100 - Train loss: 0.0401 - Val accuracy: 0.9048 - Val loss: 0.2500 - Val F1: 0.9049 - LR: 4.00e-05
# 	Epoch 70/100 - Train loss: 0.0369 - Val accuracy: 0.9182 - Val loss: 0.2090 - Val F1: 0.9182 - LR: 3.00e-05
# 	Epoch 80/100 - Train loss: 0.0296 - Val accuracy: 0.9008 - Val loss: 0.2654 - Val F1: 0.9026 - LR: 2.00e-05
# 	Epoch 90/100 - Train loss: 0.0246 - Val accuracy: 0.9182 - Val loss: 0.2022 - Val F1: 0.9181 - LR: 1.00e-05
# 	Epoch 100/100 - Train loss: 0.0243 - Val accuracy: 0.9223 - Val loss: 0.1970 - Val F1: 0.9223 - LR: 0.00e+00
# 	Best epoch: 93 - Best val accuracy: 0.9196 - Best val loss: 0.1961 - Best val F1: 0.9198
#
# Domain: 61
# x_dp_dom.shape: (623, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 61 | Accuracy: 0.7737 | Loss: 0.6990 | F1: 0.7840
#
# Domain: 62
# x_dp_dom.shape: (558, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 62 | Accuracy: 0.7384 | Loss: 1.3030 | F1: 0.6835
#
# Domain: 63
# x_dp_dom.shape: (610, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 63 | Accuracy: 0.8525 | Loss: 0.3596 | F1: 0.8525
#
# Domain: 64
# x_dp_dom.shape: (257, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 64 | Accuracy: 0.7237 | Loss: 1.6556 | F1: 0.7001
#
# Domain: 65
# x_dp_dom.shape: (586, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 65 | Accuracy: 0.8123 | Loss: 0.4015 | F1: 0.8045
#
# Domain: 66
# x_dp_dom.shape: (563, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 66 | Accuracy: 0.7389 | Loss: 0.7505 | F1: 0.6968
#
# Domain: 67
# x_dp_dom.shape: (349, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 67 | Accuracy: 0.8510 | Loss: 0.4730 | F1: 0.8364
#
# Domain: 68
# x_dp_dom.shape: (638, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 68 | Accuracy: 0.9436 | Loss: 0.1720 | F1: 0.9444
#
# Domain: 69
# x_dp_dom.shape: (572, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 69 | Accuracy: 0.8199 | Loss: 0.5244 | F1: 0.8094
#
# Domain: 70
# x_dp_dom.shape: (532, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 70 | Accuracy: 0.7068 | Loss: 1.6962 | F1: 0.6251
#
# Domain: 71
# x_dp_dom.shape: (612, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 71 | Accuracy: 0.8938 | Loss: 0.2782 | F1: 0.8940
#
# Domain: 72
# x_dp_dom.shape: (581, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 72 | Accuracy: 0.8898 | Loss: 0.2729 | F1: 0.8879
#
# Domain: 73
# x_dp_dom.shape: (577, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 73 | Accuracy: 0.8873 | Loss: 0.2826 | F1: 0.8878
#
# Domain: 74
# x_dp_dom.shape: (319, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 74 | Accuracy: 0.8464 | Loss: 0.7891 | F1: 0.8426
#
# Domain: 75
# x_dp_dom.shape: (581, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Source class: WAL | Domain: 75 | Accuracy: 0.8038 | Loss: 0.4499 | F1: 0.8012
#
# Mean accuracy for run 9: 0.8188
# Mean F1 for run 9: 0.8034
#
# Mean accuracy over 10 runs: 0.8183 +- 0.0266
# Mean F1 over 10 runs: 0.8048 +- 0.0327

# %%
# def compute_TSTR_Df_rot(dataset):
#     accs = []
#     f1s = []

#     for i in range(num_runs):

#         accs_run = []
#         f1s_run = []

#         for src_class in config[dataset]['class_names']:
#             if src_class != 'WAL':
#                 continue

#             print(f"Source class: {src_class}\n")

#             # Load Df data
#             x_df, y_df, k_df = get_data(dataset, 'df', src_class, rot=True)
#             print(f'x_df.shape: {x_df.shape} | np.unique(y_df): {np.unique(y_df)}\n')

#             # Train on Df data
#             print('Training on Df data...')
#             df_model = train_only(x_df, y_df, dataset, num_epochs=num_epochs)

#             for domain in range(config[dataset]['num_df_domains'], config[dataset]['num_df_domains'] + config[dataset]['num_dp_domains']):
#                 print(f"Domain: {domain}")

#                 # Load Dp data
#                 x_dp_dom, y_dp_dom, k_dp_dom = get_data(dataset, 'dp', src_class, domain)
#                 print(f'x_dp_dom.shape: {x_dp_dom.shape} | np.unique(y_dp_dom): {np.unique(y_dp_dom)}\n')

#                 # Evaluate on Dp data
#                 acc, loss, f1 = evaluate_model(df_model, get_dataloader(x_dp_dom, y_dp_dom))
#                 save_scores(src_class, domain, acc, loss, f1, 'Df_rot', dataset)
#                 accs_run.append(acc)
#                 f1s_run.append(f1)
#                 print(f'Source class: {src_class} | Domain: {domain} | Accuracy: {acc:.4f} | Loss: {loss:.4f} | F1: {f1:.4f}\n')

#         print(f"Mean accuracy for run {i}: {np.mean(accs_run):.4f}")
#         print(f"Mean F1 for run {i}: {np.mean(f1s_run):.4f}\n")
#         accs.append(np.mean(accs_run))
#         f1s.append(np.mean(f1s_run))

#     print(f"Mean accuracy over {num_runs} runs: {np.mean(accs):.4f} +- {np.std(accs):.4f}")
#     print(f"Mean F1 over {num_runs} runs: {np.mean(f1s):.4f} +- {np.std(f1s):.4f}\n")




# compute_TSTR_Df_rot('mobiact_realworld')

# %%
def compute_TSTR_Syn(dataset):
    accs = []
    f1s = []

    for src_class in config[dataset]['class_names']:
        if src_class != 'WAL':
            continue

        print(f"Source class: {src_class}\n")

        for domain in range(config[dataset]['num_df_domains'], config[dataset]['num_df_domains'] + config[dataset]['num_dp_domains']):
            print(f"Domain: {domain}")

            # Load synthetic data
            x_syn_dom, y_syn_dom, k_syn_dom = get_syn_data(dataset, syn_name, src_class, domain)
            print(f'x_syn_dom.shape: {x_syn_dom.shape} | np.unique(y_syn_dom): {np.unique(y_syn_dom)}')

            # Load Dp data
            x_dp_dom, y_dp_dom, k_dp_dom = get_data(dataset, 'dp', src_class, domain)
            print(f'x_dp_dom.shape: {x_dp_dom.shape} | np.unique(y_dp_dom): {np.unique(y_dp_dom)}\n')

            # Train on synthetic data and evaluate on Dp data
            print('Training on synthetic data...')
            acc, loss, f1 = train_and_test(x_syn_dom, y_syn_dom, x_dp_dom, y_dp_dom, dataset, num_epochs=num_epochs)
            save_scores(src_class, domain, acc, loss, f1, 'Syn', dataset)
            accs.append(acc)
            f1s.append(f1)
            print(f'Source class: {src_class} | Domain: {domain} | Accuracy: {acc:.4f} | Loss: {loss:.4f} | F1: {f1:.4f}\n')

    print(f"Mean accuracy: {np.mean(accs):.4f} +- {np.std(accs):.4f}")
    print(f"Mean F1: {np.mean(f1s):.4f} +- {np.std(f1s):.4f}\n")




compute_TSTR_Syn('mobiact_realworld')
# Out:
# Source class: WAL
#
# Domain: 61
# x_syn_dom.shape: (696, 3, 128) | np.unique(y_syn_dom): [1 2 3]
# x_dp_dom.shape: (623, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Training on synthetic data...
# 	Epoch 10/100 - Train loss: 0.0047 - Val accuracy: 1.0000 - Val loss: 0.0043 - Val F1: 1.0000 - LR: 9.00e-05
# 	Epoch 20/100 - Train loss: 0.0015 - Val accuracy: 1.0000 - Val loss: 0.0013 - Val F1: 1.0000 - LR: 8.00e-05
# 	Epoch 30/100 - Train loss: 0.0007 - Val accuracy: 1.0000 - Val loss: 0.0009 - Val F1: 1.0000 - LR: 7.00e-05
# 	Epoch 40/100 - Train loss: 0.0009 - Val accuracy: 1.0000 - Val loss: 0.0017 - Val F1: 1.0000 - LR: 6.00e-05
# 	Epoch 50/100 - Train loss: 0.0003 - Val accuracy: 1.0000 - Val loss: 0.0005 - Val F1: 1.0000 - LR: 5.00e-05
# 	Epoch 60/100 - Train loss: 0.0001 - Val accuracy: 1.0000 - Val loss: 0.0003 - Val F1: 1.0000 - LR: 4.00e-05
# 	Epoch 70/100 - Train loss: 0.0002 - Val accuracy: 1.0000 - Val loss: 0.0002 - Val F1: 1.0000 - LR: 3.00e-05
# 	Epoch 80/100 - Train loss: 0.0002 - Val accuracy: 1.0000 - Val loss: 0.0001 - Val F1: 1.0000 - LR: 2.00e-05
# 	Epoch 90/100 - Train loss: 0.0001 - Val accuracy: 1.0000 - Val loss: 0.0002 - Val F1: 1.0000 - LR: 1.00e-05
# 	Epoch 100/100 - Train loss: 0.0001 - Val accuracy: 1.0000 - Val loss: 0.0002 - Val F1: 1.0000 - LR: 0.00e+00
# 	Best epoch: 92 - Best val accuracy: 1.0000 - Best val loss: 0.0001 - Best val F1: 1.0000
#
# Source class: WAL | Domain: 61 | Accuracy: 0.9551 | Loss: 0.1366 | F1: 0.9545
#
# Domain: 62
# x_syn_dom.shape: (666, 3, 128) | np.unique(y_syn_dom): [1 2 3]
# x_dp_dom.shape: (558, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Training on synthetic data...
# 	Epoch 10/100 - Train loss: 0.0068 - Val accuracy: 0.9925 - Val loss: 0.0175 - Val F1: 0.9925 - LR: 9.00e-05
# 	Epoch 20/100 - Train loss: 0.0016 - Val accuracy: 0.9925 - Val loss: 0.0134 - Val F1: 0.9925 - LR: 8.00e-05
# 	Epoch 30/100 - Train loss: 0.0006 - Val accuracy: 0.9925 - Val loss: 0.0160 - Val F1: 0.9925 - LR: 7.00e-05
# 	Epoch 40/100 - Train loss: 0.0009 - Val accuracy: 0.9925 - Val loss: 0.0131 - Val F1: 0.9925 - LR: 6.00e-05
# 	Epoch 50/100 - Train loss: 0.0004 - Val accuracy: 0.9925 - Val loss: 0.0115 - Val F1: 0.9925 - LR: 5.00e-05
# 	Epoch 60/100 - Train loss: 0.0003 - Val accuracy: 0.9925 - Val loss: 0.0114 - Val F1: 0.9925 - LR: 4.00e-05
# 	Epoch 70/100 - Train loss: 0.0002 - Val accuracy: 0.9925 - Val loss: 0.0100 - Val F1: 0.9925 - LR: 3.00e-05
# 	Epoch 80/100 - Train loss: 0.0001 - Val accuracy: 0.9925 - Val loss: 0.0130 - Val F1: 0.9925 - LR: 2.00e-05
# 	Epoch 90/100 - Train loss: 0.0003 - Val accuracy: 0.9925 - Val loss: 0.0133 - Val F1: 0.9925 - LR: 1.00e-05
# 	Epoch 100/100 - Train loss: 0.0002 - Val accuracy: 0.9925 - Val loss: 0.0175 - Val F1: 0.9925 - LR: 0.00e+00
# 	Best epoch: 49 - Best val accuracy: 0.9925 - Best val loss: 0.0071 - Best val F1: 0.9925
#
# Source class: WAL | Domain: 62 | Accuracy: 0.8065 | Loss: 0.6538 | F1: 0.8018
#
# Domain: 63
# x_syn_dom.shape: (747, 3, 128) | np.unique(y_syn_dom): [1 2 3]
# x_dp_dom.shape: (610, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Training on synthetic data...
# 	Epoch 10/100 - Train loss: 0.0071 - Val accuracy: 1.0000 - Val loss: 0.0042 - Val F1: 1.0000 - LR: 9.00e-05
# 	Epoch 20/100 - Train loss: 0.0019 - Val accuracy: 1.0000 - Val loss: 0.0011 - Val F1: 1.0000 - LR: 8.00e-05
# 	Epoch 30/100 - Train loss: 0.0012 - Val accuracy: 1.0000 - Val loss: 0.0005 - Val F1: 1.0000 - LR: 7.00e-05
# 	Epoch 40/100 - Train loss: 0.0003 - Val accuracy: 1.0000 - Val loss: 0.0003 - Val F1: 1.0000 - LR: 6.00e-05
# 	Epoch 50/100 - Train loss: 0.0014 - Val accuracy: 1.0000 - Val loss: 0.0003 - Val F1: 1.0000 - LR: 5.00e-05
# 	Epoch 60/100 - Train loss: 0.0002 - Val accuracy: 1.0000 - Val loss: 0.0002 - Val F1: 1.0000 - LR: 4.00e-05
# 	Epoch 70/100 - Train loss: 0.0002 - Val accuracy: 1.0000 - Val loss: 0.0002 - Val F1: 1.0000 - LR: 3.00e-05
# 	Epoch 80/100 - Train loss: 0.0001 - Val accuracy: 1.0000 - Val loss: 0.0001 - Val F1: 1.0000 - LR: 2.00e-05
# 	Epoch 90/100 - Train loss: 0.0001 - Val accuracy: 1.0000 - Val loss: 0.0001 - Val F1: 1.0000 - LR: 1.00e-05
# 	Epoch 100/100 - Train loss: 0.0001 - Val accuracy: 1.0000 - Val loss: 0.0001 - Val F1: 1.0000 - LR: 0.00e+00
# 	Best epoch: 90 - Best val accuracy: 1.0000 - Best val loss: 0.0001 - Best val F1: 1.0000
#
# Source class: WAL | Domain: 63 | Accuracy: 0.7000 | Loss: 1.0705 | F1: 0.6939
#
# Domain: 64
# x_syn_dom.shape: (672, 3, 128) | np.unique(y_syn_dom): [1 2 3]
# x_dp_dom.shape: (257, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Training on synthetic data...
# 	Epoch 10/100 - Train loss: 0.0063 - Val accuracy: 0.9926 - Val loss: 0.0279 - Val F1: 0.9926 - LR: 9.00e-05
# 	Epoch 20/100 - Train loss: 0.0015 - Val accuracy: 0.9926 - Val loss: 0.0305 - Val F1: 0.9926 - LR: 8.00e-05
# 	Epoch 30/100 - Train loss: 0.0012 - Val accuracy: 0.9926 - Val loss: 0.0371 - Val F1: 0.9926 - LR: 7.00e-05
# 	Epoch 40/100 - Train loss: 0.
- LR: 7.00e-05
# 	Epoch 40/100 - Train loss: 0.0027 - Val accuracy: 0.8980 - Val loss: 0.2652 - Val F1: 0.8980 - LR: 6.00e-05
# 	Epoch 50/100 - Train loss: 0.0023 - Val accuracy: 0.9796 - Val loss: 0.0893 - Val F1: 0.9797 - LR: 5.00e-05
# 	Epoch 60/100 - Train loss: 0.0019 - Val accuracy: 0.7551 - Val loss: 0.5143 - Val F1: 0.7213 - LR: 4.00e-05
# 	Epoch 70/100 - Train loss: 0.0021 - Val accuracy: 0.6599 - Val loss: 0.7016 - Val F1: 0.6138 - LR: 3.00e-05
# 	Epoch 80/100 - Train loss: 0.0015 - Val accuracy: 0.8912 - Val loss: 0.2473 - Val F1: 0.8894 - LR: 2.00e-05
# 	Epoch 90/100 - Train loss: 0.0034 - Val accuracy: 0.3741 - Val loss: 2.3528 - Val F1: 0.2456 - LR: 1.00e-05
# 	Epoch 100/100 - Train loss: 0.0043 - Val accuracy: 0.4966 - Val loss: 1.2659 - Val F1: 0.4232 - LR: 0.00e+00
# 	Best epoch: 45 - Best val accuracy: 0.9796 - Best val loss: 0.0691 - Best val F1: 0.9796
#
# Source class: WAL | Domain: 74 | Accuracy: 0.7524 | Loss: 1.9975 | F1: 0.6883
#
# Domain: 75
# x_syn_dom.shape: (726, 3, 128) | np.unique(y_syn_dom): [1 2 3]
# x_dp_dom.shape: (581, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Training on synthetic data...
# 	Epoch 10/100 - Train loss: 0.0308 - Val accuracy: 0.3356 - Val loss: 4.5502 - Val F1: 0.1687 - LR: 9.00e-05
# 	Epoch 20/100 - Train loss: 0.0125 - Val accuracy: 0.3356 - Val loss: 5.7601 - Val F1: 0.1687 - LR: 8.00e-05
# 	Epoch 30/100 - Train loss: 0.0045 - Val accuracy: 0.3356 - Val loss: 5.9503 - Val F1: 0.1687 - LR: 7.00e-05
# 	Epoch 40/100 - Train loss: 0.0062 - Val accuracy: 0.3356 - Val loss: 6.2766 - Val F1: 0.1687 - LR: 6.00e-05
# 	Epoch 50/100 - Train loss: 0.0128 - Val accuracy: 0.3356 - Val loss: 7.1447 - Val F1: 0.1687 - LR: 5.00e-05
# 	Epoch 60/100 - Train loss: 0.0007 - Val accuracy: 0.3356 - Val loss: 5.7748 - Val F1: 0.1687 - LR: 4.00e-05
# 	Epoch 70/100 - Train loss: 0.0010 - Val accuracy: 0.3356 - Val loss: 5.9849 - Val F1: 0.1687 - LR: 3.00e-05
# 	Epoch 80/100 - Train loss: 0.0012 - Val accuracy: 0.3356 - Val loss: 6.5924 - Val F1: 0.1687 - LR: 2.00e-05
# 	Epoch 90/100 - Train loss: 0.0008 - Val accuracy: 0.3356 - Val loss: 6.7770 - Val F1: 0.1687 - LR: 1.00e-05
# 	Epoch 100/100 - Train loss: 0.0006 - Val accuracy: 0.3356 - Val loss: 7.4457 - Val F1: 0.1687 - LR: 0.00e+00
# 	Best epoch: 1 - Best val accuracy: 0.3356 - Best val loss: 1.1003 - Best val F1: 0.1687
#
# Source class: WAL | Domain: 75 | Accuracy: 0.3460 | Loss: 10.1727 | F1: 0.1778
#
# Mean accuracy: 0.4530 +- 0.1360
# Mean F1: 0.3184 +- 0.1827

# %%
# def compute_TSTR_Syn_all(dataset):
#     accs = []

#     for src_class in config[dataset]['class_names']:
#         if src_class != 'WAL':
#             continue

#         print(f"Source class: {src_class}\n")

#         # Load synthetic data
#         x_syn, y_syn, k_syn = get_syn_data(dataset, syn_name, src_class)
#         print(f'x_syn.shape: {x_syn.shape} | np.unique(y_syn): {np.unique(y_syn)}')

#         # Load Dp data
#         x_dp, y_dp, k_dp = get_data(dataset, 'dp', src_class)
#         print(f'x_dp.shape: {x_dp.shape} | np.unique(y_dp): {np.unique(y_dp)}\n')

#         # Train on synthetic data and evaluate on Dp data
#         print('Training on synthetic data...')
#         acc, loss = train_and_test(x_syn, y_syn, x_dp, y_dp, dataset, num_epochs=num_epochs)
#         save_scores(src_class, 100, acc, loss, 'Syn_all', dataset)
#         accs.append(acc)
#         print(f'Source class: {src_class} | Domain: All | Accuracy: {acc:.4f} | Loss: {loss:.4f}\n')

#     print(f"Mean accuracy: {np.mean(accs):.4f}\n")




# compute_TSTR_Syn_all('mobiact_realworld')

# %%
def compute_TSTR_Df_Syn(dataset):
    accs = []
    f1s = []

    for src_class in config[dataset]['class_names']:
        if src_class != 'WAL':
            continue

        print(f"Source class: {src_class}\n")

        # Load Df data
        x_df, y_df, k_df = get_data(dataset, 'df', src_class)
        print(f'x_df.shape: {x_df.shape} | np.unique(y_df): {np.unique(y_df)}\n')

        # Train on Df data
        print('Training on Df data...')
        df_model = train_only(x_df, y_df, dataset, num_epochs=num_epochs)

        for domain in range(config[dataset]['num_df_domains'], config[dataset]['num_df_domains'] + config[dataset]['num_dp_domains']):
            print(f"Domain: {domain}")

            # Load synthetic data
            x_syn_dom, y_syn_dom, k_syn_dom = get_syn_data(dataset, syn_name, src_class, domain)
            print(f'x_syn_dom.shape: {x_syn_dom.shape} | np.unique(y_syn_dom): {np.unique(y_syn_dom)}')

            # Load Dp data
            x_dp_dom, y_dp_dom, k_dp_dom = get_data(dataset, 'dp', src_class, domain)
            print(f'x_dp_dom.shape: {x_dp_dom.shape} | np.unique(y_dp_dom): {np.unique(y_dp_dom)}\n')

            # Fine-tune Df model on synthetic data and evaluate on Dp data
            print('Fine-tuning on synthetic data...')
            df_syn_model = fine_tune(copy.deepcopy(df_model), x_syn_dom, y_syn_dom, num_epochs=num_epochs)
            acc, loss, f1 = evaluate_model(df_syn_model, get_dataloader(x_dp_dom, y_dp_dom))
            save_scores(src_class, domain, acc, loss, f1, 'Df_Syn', dataset)
            accs.append(acc)
            f1s.append(f1)
            print(f'Source class: {src_class} | Domain: {domain} | Accuracy: {acc:.4f} | Loss: {loss:.4f} | F1: {f1:.4f}\n')

    print(f"Mean accuracy: {np.mean(accs):.4f} +- {np.std(accs):.4f}")
    print(f"Mean F1: {np.mean(f1s):.4f} +- {np.std(f1s):.4f}\n")




compute_TSTR_Df_Syn('mobiact_realworld')
# Out:
# Source class: WAL
#
# x_df.shape: (3729, 3, 128) | np.unique(y_df): [1 2 3]
#
# Training on Df data...
# 	Epoch 10/100 - Train loss: 0.0428 - Val accuracy: 0.9893 - Val loss: 0.0359 - Val F1: 0.9892 - LR: 9.00e-05
# 	Epoch 20/100 - Train loss: 0.0135 - Val accuracy: 0.9920 - Val loss: 0.0243 - Val F1: 0.9919 - LR: 8.00e-05
# 	Epoch 30/100 - Train loss: 0.0034 - Val accuracy: 0.9933 - Val loss: 0.0192 - Val F1: 0.9933 - LR: 7.00e-05
# 	Epoch 40/100 - Train loss: 0.0063 - Val accuracy: 0.9946 - Val loss: 0.0207 - Val F1: 0.9946 - LR: 6.00e-05
# 	Epoch 50/100 - Train loss: 0.0013 - Val accuracy: 0.9946 - Val loss: 0.0142 - Val F1: 0.9946 - LR: 5.00e-05
# 	Epoch 60/100 - Train loss: 0.0006 - Val accuracy: 0.9960 - Val loss: 0.0156 - Val F1: 0.9960 - LR: 4.00e-05
# 	Epoch 70/100 - Train loss: 0.0007 - Val accuracy: 0.9960 - Val loss: 0.0115 - Val F1: 0.9960 - LR: 3.00e-05
# 	Epoch 80/100 - Train loss: 0.0008 - Val accuracy: 0.9960 - Val loss: 0.0126 - Val F1: 0.9960 - LR: 2.00e-05
# 	Epoch 90/100 - Train loss: 0.0006 - Val accuracy: 0.9960 - Val loss: 0.0114 - Val F1: 0.9960 - LR: 1.00e-05
# 	Epoch 100/100 - Train loss: 0.0005 - Val accuracy: 0.9960 - Val loss: 0.0139 - Val F1: 0.9960 - LR: 0.00e+00
# 	Best epoch: 90 - Best val accuracy: 0.9960 - Best val loss: 0.0114 - Best val F1: 0.9960
#
# Domain: 61
# x_syn_dom.shape: (696, 3, 128) | np.unique(y_syn_dom): [1 2 3]
# x_dp_dom.shape: (623, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Fine-tuning on synthetic data...
# 	Epoch 10/100 - Train loss: 1.1182 - Val accuracy: 0.6786 - Val loss: 0.9531 - Val F1: 0.6802 - LR: 9.00e-06
# 	Epoch 20/100 - Train loss: 0.8302 - Val accuracy: 0.7214 - Val loss: 0.7596 - Val F1: 0.7254 - LR: 8.00e-06
# 	Epoch 30/100 - Train loss: 0.6830 - Val accuracy: 0.7571 - Val loss: 0.6489 - Val F1: 0.7569 - LR: 7.00e-06
# 	Epoch 40/100 - Train loss: 0.6182 - Val accuracy: 0.7929 - Val loss: 0.5453 - Val F1: 0.7930 - LR: 6.00e-06
# 	Epoch 50/100 - Train loss: 0.5207 - Val accuracy: 0.8286 - Val loss: 0.4634 - Val F1: 0.8294 - LR: 5.00e-06
# 	Epoch 60/100 - Train loss: 0.4369 - Val accuracy: 0.8286 - Val loss: 0.4110 - Val F1: 0.8294 - LR: 4.00e-06
# 	Epoch 70/100 - Train loss: 0.4300 - Val accuracy: 0.8357 - Val loss: 0.3860 - Val F1: 0.8365 - LR: 3.00e-06
# 	Epoch 80/100 - Train loss: 0.3851 - Val accuracy: 0.8500 - Val loss: 0.3631 - Val F1: 0.8498 - LR: 2.00e-06
# 	Epoch 90/100 - Train loss: 0.3746 - Val accuracy: 0.8357 - Val loss: 0.3433 - Val F1: 0.8365 - LR: 1.00e-06
# 	Epoch 100/100 - Train loss: 0.3929 - Val accuracy: 0.8357 - Val loss: 0.3357 - Val F1: 0.8365 - LR: 0.00e+00
# 	Best epoch: 100 - Best val accuracy: 0.8357 - Best val loss: 0.3357 - Best val F1: 0.8365
#
# Source class: WAL | Domain: 61 | Accuracy: 0.9342 | Loss: 0.1847 | F1: 0.9346
#
# Domain: 62
# x_syn_dom.shape: (666, 3, 128) | np.unique(y_syn_dom): [1 2 3]
# x_dp_dom.shape: (558, 3, 128) | np.unique(y_dp_dom): [1 2 3]
#
# Fine-tuning on synthetic data...
# 	Epoch 10/100 - Train loss: 0.3796 - Val accuracy: 0.8657 - Val loss: 0.4189 - Val F1: 0.8648 - LR: 9.00e-06
# 	Epoch 20/100 - Train loss: 0.3249 - Val accuracy: 0.8731 - Val loss: 0.3494 - Val F1: 0.8724 - LR: 8.00e-06
# 	Epoch 30/100 - Train loss: 0
- LR: 0.00e+00
# 	Best epoch: 100 - Best val accuracy: 0.9521 - Best val loss: 0.1209 - Best val F1: 0.9520
#
# Source class: WAL | Domain: 75 | Accuracy: 0.6076 | Loss: 2.1854 | F1: 0.5901
#
# Mean accuracy: 0.7938 +- 0.1096
# Mean F1: 0.7823 +- 0.1195

# %%
# def compute_TSTR_Df_Syn_all(dataset):
#     accs = []

#     for src_class in config[dataset]['class_names']:
#         if src_class != 'WAL':
#             continue

#         print(f"Source class: {src_class}\n")

#         # Load Df data
#         x_df, y_df, k_df = get_data(dataset, 'df', src_class)
#         print(f'x_df.shape: {x_df.shape} | np.unique(y_df): {np.unique(y_df)}\n')

#         # Train on Df data
#         print('Training on Df data...')
#         df_model = train_only(x_df, y_df, dataset, num_epochs=num_epochs)

#         # Load synthetic data
#         x_syn, y_syn, k_syn = get_syn_data(dataset, syn_name, src_class)
#         print(f'x_syn.shape: {x_syn.shape} | np.unique(y_syn): {np.unique(y_syn)}')

#         # Load Dp data
#         x_dp, y_dp, k_dp = get_data(dataset, 'dp', src_class)
#         print(f'x_dp.shape: {x_dp.shape} | np.unique(y_dp): {np.unique(y_dp)}\n')

#         # Fine-tune Df model on synthetic data and evaluate on Dp data
#         print('Fine-tuning on synthetic data...')
#         df_syn_model = fine_tune(copy.deepcopy(df_model), x_syn, y_syn, num_epochs=num_epochs)
#         acc, loss = evaluate_model(df_syn_model, get_dataloader(x_dp, y_dp))
#         save_scores(src_class, 100, acc, loss, 'Df_Syn_all', dataset)
#         accs.append(acc)
#         print(f'Source class: {src_class} | Domain: All | Accuracy: {acc:.4f} | Loss: {loss:.4f}\n')

#     print(f"Mean accuracy: {np.mean(accs):.4f}\n")




# compute_TSTR_Df_Syn_all('mobiact_realworld')

# %%
def compute_TSTR_Df_plus_Syn(dataset):
    accs = []
    f1s = []

    for src_class in config[dataset]['class_names']:
        if src_class != 'WAL':
            continue

        print(f"Source class: {src_class}\n")

        # Load Df data
        x_df, y_df, k_df = get_data(dataset, 'df', src_class)
        print(f'x_df.shape: {x_df.shape} | np.unique(y_df): {np.unique(y_df)}\n')

        for domain in range(config[dataset]['num_df_domains'], config[dataset]['num_df_domains'] + config[dataset]['num_dp_domains']):
            print(f"Domain: {domain}")

            # Load synthetic data
            x_syn_dom, y_syn_dom, k_syn_dom = get_syn_data(dataset, syn_name, src_class, domain)
            print(f'x_syn_dom.shape: {x_syn_dom.shape} | np.unique(y_syn_dom): {np.unique(y_syn_dom)}')

            # Load Dp data
            x_dp_dom, y_dp_dom, k_dp_dom = get_data(dataset, 'dp', src_class, domain)
            print(f'x_dp_dom.shape: {x_dp_dom.shape} | np.unique(y_dp_dom): {np.unique(y_dp_dom)}\n')

            # Join Df and synthetic data
            x_df_syn = np.concatenate([x_df, x_syn_dom], axis=0)
            y_df_syn = np.concatenate([y_df, y_syn_dom], axis=0)
            k_df_syn = np.concatenate([k_df, k_syn_dom], axis=0)
            print(f'x_df_syn.shape: {x_df_syn.shape} | np.unique(y_df_syn): {np.unique(y_df_syn)}')

            # Train on Df plus synthetic data and test on Dp data
            print('Training on Df plus synthetic data...')
            acc, loss, f1 = train_and_test(x_df, y_df, x_dp_dom, y_dp_dom, dataset, num_epochs=num_epochs)
            save_scores(src_class, domain, acc, loss, f1, 'Df_plus_Syn', dataset)
            accs.append(acc)
            f1s.append(f1)
            print(f'Source class: {src_class} | Domain: {domain} | Accuracy: {acc:.4f} | Loss: {loss:.4f} | F1: {f1:.4f}\n')

    print(f"Mean accuracy: {np.mean(accs):.4f} +- {np.std(accs):.4f}")
    print(f"Mean F1: {np.mean(f1s):.4f} +- {np.std(f1s):.4f}\n")




compute_TSTR_Df_plus_Syn('mobiact_realworld')
# Out:
# Source class: WAL
#
# x_df.shape: (3729, 3, 128) | np.unique(y_df): [1 2 3]
#
# Domain: 61
# x_syn_dom.shape: (696, 3, 128) | np.unique(y_syn_dom): [1 2 3]
# x_dp_dom.shape:
# 	Epoch 30/100 - Train loss: 0.0121 - Val accuracy: 0.9946 - Val loss: 0.0162 - Val F1: 0.9946 - LR: 7.00e-05
# 	Epoch 40/100 - Train loss: 0.0016 - Val accuracy: 0.9960 - Val loss: 0.0223 - Val F1: 0.9960 - LR: 6.00e-05
# 	Epoch 50/100 - Train loss: 0.0010 - Val accuracy: 0.9946 - Val loss: 0.0123 - Val F1: 0.9946 - LR: 5.00e-05
# 	Epoch 60/100 - Train loss: 0.0013 - Val accuracy: 0.9946 - Val loss: 0.0103 - Val F1: 0.9946 - LR: 4.00e-05
# 	Epoch 70/100 - Train loss: 0.0006 - Val accuracy: 0.9946 - Val loss: 0.0106 - Val F1: 0.9946 - LR: 3.00e-05
# 	Epoch 80/100 - Train loss: 0.0007 - Val accuracy: 0.9946 - Val loss: 0.0099 - Val F1: 0.9946 - LR: 2.00e-05
# 	Epoch 90/100 - Train loss: 0.0005 - Val accuracy: 0.9946 - Val loss: 0.0121 - Val F1: 0.9946 - LR: 1.00e-05
# 	Epoch 100/100 - Train loss: 0.0006 - Val accuracy: 0.9946 - Val loss: 0.0106 - Val F1: 0.9946 - LR: 0.00e+00
# 	Best epoch: 72 - Best val accuracy: 0.9973 - Best val loss: 0.0091 - Best val F1: 0.9973
#
# Source class: WAL | Domain: 75 | Accuracy: 0.8520 | Loss: 0.4332 | F1: 0.8496
#
# Mean accuracy: 0.7618 +- 0.0947
# Mean F1: 0.7363 +- 0.1113

# %% [markdown]
# # TSTRFS

# %%
def compute_TSTRFS_Dpfs(dataset):
    accs = []

    for src_class in config[dataset]['class_names']:
        if src_class != 'WAL':
            continue

        print(f"Source class: {src_class}\n")

        for domain in range(config[dataset]['num_df_domains'], config[dataset]['num_df_domains'] + config[dataset]['num_dp_domains']):
            print(f"Domain: {domain}")

            # Load Dpfs data
            x_dpfs_dom, y_dpfs_dom, k_dpfs_dom = get_data(dataset, 'dpfs', src_class, domain)
            print(f'x_dpfs_dom.shape: {x_dpfs_dom.shape} | np.unique(y_dpfs_dom): {np.unique(y_dpfs_dom)}')

            # Load Dp data
            x_dp_dom, y_dp_dom, k_dp_dom = get_data(dataset, 'dp', src_class, domain)
            print(f'x_dp_dom.shape: {x_dp_dom.shape} | np.unique(y_dp_dom): {np.unique(y_dp_dom)}\n')

            # Train on Dpfs data and test on Dp data
            print('Training on Dpfs data...')
            acc, loss = train_and_test(x_dpfs_dom, y_dpfs_dom, x_dp_dom, y_dp_dom, dataset, num_epochs=num_epochs)
            save_scores(src_class, domain, acc, loss, 'FS_Dpfs', dataset)
            accs.append(acc)
            print(f'Source class: {src_class} | Domain: {domain} | Accuracy: {acc:.4f} | Loss: {loss:.4f}\n')

    print(f"Mean accuracy: {np.mean(accs):.4f}\n")



compute_TSTRFS_Dpfs('mobiact_realworld')

# %%
def compute_TSTRFS_Df_Dpfs(dataset):
    accs = []

    for src_class in config[dataset]['class_names']:
        if src_class != 'WAL':
            continue

        print(f"Source class: {src_class}\n")

        # Load Df data
        x_df, y_df, k_df = get_data(dataset, 'df', src_class)
        print(f'x_df.shape: {x_df.shape} | np.unique(y_df): {np.unique(y_df)}\n')

        # Train on Df data
        print('Training on Df data...')
        df_model = train_only(x_df, y_df, dataset, num_epochs=num_epochs)

        for domain in range(config[dataset]['num_df_domains'], config[dataset]['num_df_domains'] + config[dataset]['num_dp_domains']):
            print(f"Domain: {domain}")

            # Load Dpfs data
            x_dpfs_dom, y_dpfs_dom, k_dpfs_dom = get_data(dataset, 'dpfs', src_class, domain)
            print(f'x_dpfs_dom.shape: {x_dpfs_dom.shape} | np.unique(y_dpfs_dom): {np.unique(y_dpfs_dom)}')

            # Load Dp data
            x_dp_dom, y_dp_dom, k_dp_dom = get_data(dataset, 'dp', src_class, domain)
            print(f'x_dp_dom.shape: {x_dp_dom.shape} | np.unique(y_dp_dom): {np.unique(y_dp_dom)}\n')

            # Fine-tune Df model on Dpfs data and test on Dp data
            print('Fine-tuning on Dpfs data...')
            df_dpfs_model = fine_tune(copy.deepcopy(df_model), x_dpfs_dom, y_dpfs_dom, num_epochs=num_epochs)
            acc, loss = evaluate_model(df_dpfs_model, get_dataloader(x_dp_dom, y_dp_dom))
            save_scores(src_class, domain, acc, loss, 'FS_Df_Dpfs', dataset)
            accs.append(acc)
            print(f'Source class: {src_class} | Domain: {domain} | Accuracy: {acc:.4f} | Loss: {loss:.4f}\n')

    print(f"Mean accuracy: {np.mean(accs):.4f}\n")



compute_TSTRFS_Df_Dpfs('mobiact_realworld')

# %%
def compute_TSTRFS_Syn(dataset):
    accs = []

    for src_class in config[dataset]['class_names']:
        if src_class != 'WAL':
            continue

        print(f"Source class: {src_class}\n")

        for domain in range(config[dataset]['num_df_domains'], config[dataset]['num_df_domains'] + config[dataset]['num_dp_domains']):
            print(f"Domain: {domain}")

            # Load synthetic data
            x_syn_dom, y_syn_dom, k_syn_dom = get_syn_data(dataset, syn_name, src_class, domain)
            print(f'x_syn_dom.shape: {x_syn_dom.shape} | np.unique(y_syn_dom): {np.unique(y_syn_dom)}')

            # Load Dp data
            x_dp_dom, y_dp_dom, k_dp_dom = get_data(dataset, 'dp', src_class, domain)
            print(f'x_dp_dom.shape: {x_dp_dom.shape} | np.unique(y_dp_dom): {np.unique(y_dp_dom)}\n')

            # Train on synthetic data and evaluate on Dp data
            print('Training on synthetic data...')
            acc, loss = train_and_test(x_syn_dom, y_syn_dom, x_dp_dom, y_dp_dom, dataset, num_epochs=num_epochs)
            save_scores(src_class, domain, acc, loss, 'FS_Syn', dataset)
            accs.append(acc)
            print(f'Source class: {src_class} | Domain: {domain} | Accuracy: {acc:.4f} | Loss: {loss:.4f}\n')

    print(f"Mean accuracy: {np.mean(accs):.4f}\n")




compute_TSTRFS_Syn('mobiact_realworld')

# %%
def compute_TSTRFS_Df_Syn(dataset):
    accs = []

    for src_class in config[dataset]['class_names']:
        if src_class != 'WAL':
            continue

        print(f"Source class: {src_class}\n")

        # Load Df data
        x_df, y_df, k_df = get_data(dataset, 'df', src_class)
        print(f'x_df.shape: {x_df.shape} | np.unique(y_df): {np.unique(y_df)}\n')

        # Train on Df data
        print('Training on Df data...')
        df_model = train_only(x_df, y_df, dataset, num_epochs=num_epochs)

        for domain in range(config[dataset]['num_df_domains'], config[dataset]['num_df_domains'] + config[dataset]['num_dp_domains']):
            print(f"Domain: {domain}")

            # Load synthetic data
            x_syn_dom, y_syn_dom, k_syn_dom = get_syn_data(dataset, syn_name, src_class, domain)
            print(f'x_syn_dom.shape: {x_syn_dom.shape} | np.unique(y_syn_dom): {np.unique(y_syn_dom)}')

            # Load Dp data
            x_dp_dom, y_dp_dom, k_dp_dom = get_data(dataset, 'dp', src_class, domain)
            print(f'x_dp_dom.shape: {x_dp_dom.shape} | np.unique(y_dp_dom): {np.unique(y_dp_dom)}\n')

            # Fine-tune Df model on synthetic data and evaluate on Dp data
            print('Fine-tuning on synthetic data...')
            df_syn_model = fine_tune(copy.deepcopy(df_model), x_syn_dom, y_syn_dom, num_epochs=num_epochs)
            acc, loss = evaluate_model(df_syn_model, get_dataloader(x_dp_dom, y_dp_dom))
            save_scores(src_class, domain, acc, loss, 'FS_Df_Syn', dataset)
            accs.append(acc)
            print(f'Source class: {src_class} | Domain: {domain} | Accuracy: {acc:.4f} | Loss: {loss:.4f}\n')

    print(f"Mean accuracy: {np.mean(accs):.4f}\n")




compute_TSTRFS_Df_Syn('mobiact_realworld')

# %%
def compute_TSTRFS_Syn_Dpfs(dataset):
    accs = []

    for src_class in config[dataset]['class_names']:
        if src_class != 'WAL':
            continue

        print(f"Source class: {src_class}\n")

        for domain in range(config[dataset]['num_df_domains'], config[dataset]['num_df_domains'] + config[dataset]['num_dp_domains']):
            print(f"Domain: {domain}")

            # Load synthetic data
            x_syn_dom, y_syn_dom, k_syn_dom = get_syn_data(dataset, syn_name, src_class, domain)
            print(f'x_syn_dom.shape: {x_syn_dom.shape} | np.unique(y_syn_dom): {np.unique(y_syn_dom)}')

            # Load Dpfs data
            x_dpfs_dom, y_dpfs_dom, k_dpfs_dom = get_data(dataset, 'dpfs', src_class, domain)
            print(f'x_dpfs_dom.shape: {x_dpfs_dom.shape} | np.unique(y_dpfs_dom): {np.unique(y_dpfs_dom)}')

            # Load Dp data
            x_dp_dom, y_dp_dom, k_dp_dom = get_data(dataset, 'dp', src_class, domain)
            print(f'x_dp_dom.shape: {x_dp_dom.shape} | np.unique(y_dp_dom): {np.unique(y_dp_dom)}\n')

            # Train on synthetic data
            print('Training on synthetic data...')
            syn_model = train_only(x_syn_dom, y_syn_dom, dataset, num_epochs=num_epochs)

            # Fine-tune synthetic model on Dpfs data and evaluate on Dp data
            print('Fine-tuning on Dpfs data...')
            syn_dpfs_model = fine_tune(copy.deepcopy(syn_model), x_dpfs_dom, y_dpfs_dom, num_epochs=num_epochs)
            acc, loss = evaluate_model(syn_dpfs_model, get_dataloader(x_dp_dom, y_dp_dom))
            save_scores(src_class, domain, acc, loss, 'FS_Syn_Dpfs', dataset)
            accs.append(acc)
            print(f'Source class: {src_class} | Domain: {domain} | Accuracy: {acc:.4f} | Loss: {loss:.4f}\n')

    print(f"Mean accuracy: {np.mean(accs):.4f}\n")




compute_TSTRFS_Syn_Dpfs('mobiact_realworld')

# %%
def compute_TSTRFS_Df_Syn_Dpfs(dataset):
    accs = []

    for src_class in config[dataset]['class_names']:
        if src_class != 'WAL':
            continue

        print(f"Source class: {src_class}\n")

        # Load Df data
        x_df, y_df, k_df = get_data(dataset, 'df', src_class)
        print(f'x_df.shape: {x_df.shape} | np.unique(y_df): {np.unique(y_df)}\n')

        # Train on Df data
        print('Training on Df data...')
        df_model = train_only(x_df, y_df, dataset, num_epochs=num_epochs)

        for domain in range(config[dataset]['num_df_domains'], config[dataset]['num_df_domains'] + config[dataset]['num_dp_domains']):
            print(f"Domain: {domain}")

            # Load synthetic data
            x_syn_dom, y_syn_dom, k_syn_dom = get_syn_data(dataset, syn_name, src_class, domain)
            print(f'x_syn_dom.shape: {x_syn_dom.shape} | np.unique(y_syn_dom): {np.unique(y_syn_dom)}')

            # Load Dpfs data
            x_dpfs_dom, y_dpfs_dom, k_dpfs_dom = get_data(dataset, 'dpfs', src_class, domain)
            print(f'x_dpfs_dom.shape: {x_dpfs_dom.shape} | np.unique(y_dpfs_dom): {np.unique(y_dpfs_dom)}')

            # Load Dp data
            x_dp_dom, y_dp_dom, k_dp_dom = get_data(dataset, 'dp', src_class, domain)
            print(f'x_dp_dom.shape: {x_dp_dom.shape} | np.unique(y_dp_dom): {np.unique(y_dp_dom)}\n')

            # Fine-tune Df model on synthetic data
            print('Fine-tuning on synthetic data...')
            df_syn_model = fine_tune(copy.deepcopy(df_model), x_syn_dom, y_syn_dom, num_epochs=num_epochs)

            # Fine-tune Df-syn model on Dpfs data and evaluate on Dp data
            print('Fine-tuning on Dpfs data...')
            df_syn_dpfs_model = fine_tune(copy.deepcopy(df_syn_model), x_dpfs_dom, y_dpfs_dom, num_epochs=num_epochs)
            acc, loss = evaluate_model(df_syn_dpfs_model, get_dataloader(x_dp_dom, y_dp_dom))
            save_scores(src_class, domain, acc, loss, 'FS_Df_Syn_Dpfs', dataset)
            accs.append(acc)
            print(f'Source class: {src_class} | Domain: {domain} | Accuracy: {acc:.4f} | Loss: {loss:.4f}\n')

    print(f"Mean accuracy: {np.mean(accs):.4f}\n")




compute_TSTRFS_Df_Syn_Dpfs('mobiact_realworld')

# %%
def compute_TSTRFS_Df_plus_Dpfs(dataset):
    accs = []

    for src_class in config[dataset]['class_names']:
        if src_class != 'WAL':
            continue

        print(f"Source class: {src_class}\n")

        # Load Df data
        x_df, y_df, k_df = get_data(dataset, 'df', src_class)
        print(f'x_df.shape: {x_df.shape} | np.unique(y_df): {np.unique(y_df)}\n')

        for domain in range(config[dataset]['num_df_domains'], config[dataset]['num_df_domains'] + config[dataset]['num_dp_domains']):
            print(f"Domain: {domain}")

            # Load Dpfs data
            x_dpfs_dom, y_dpfs_dom, k_dpfs_dom = get_data(dataset, 'dpfs', src_class, domain)
            print(f'x_dpfs_dom.shape: {x_dpfs_dom.shape} | np.unique(y_dpfs_dom): {np.unique(y_dpfs_dom)}')

            # Join Df and Dpfs data
            x_df_dpfs = np.concatenate([x_df, x_dpfs_dom], axis=0)
            y_df_dpfs = np.concatenate([y_df, y_dpfs_dom], axis=0)
            k_df_dpfs = np.concatenate([k_df, k_dpfs_dom], axis=0)
            print(f'x_df_dpfs.shape: {x_df_dpfs.shape} | np.unique(y_df_dpfs): {np.unique(y_df_dpfs)}')

            # Load Dp data
            x_dp_dom, y_dp_dom, k_dp_dom = get_data(dataset, 'dp', src_class, domain)
            print(f'x_dp_dom.shape: {x_dp_dom.shape} | np.unique(y_dp_dom): {np.unique(y_dp_dom)}\n')

            # Train on Df plus Dpfs data and test on Dp data
            print('Training on Df plus Dpfs data...')
            acc, loss = train_and_test(x_df_dpfs, y_df_dpfs, x_dp_dom, y_dp_dom, dataset, num_epochs=num_epochs)
            save_scores(src_class, domain, acc, loss, 'FS_Df_plus_Dpfs', dataset)
            accs.append(acc)
            print(f'Source class: {src_class} | Domain: {domain} | Accuracy: {acc:.4f} | Loss: {loss:.4f}\n')

    print(f"Mean accuracy: {np.mean(accs):.4f}\n")



compute_TSTRFS_Df_plus_Dpfs('mobiact_realworld')

# %%
def compute_TSTRFS_Df_plus_Syn(dataset):
    accs = []

    for src_class in config[dataset]['class_names']:
        if src_class != 'WAL':
            continue

        print(f"Source class: {src_class}\n")

        # Load Df data
        x_df, y_df, k_df = get_data(dataset, 'df', src_class)
        print(f'x_df.shape: {x_df.shape} | np.unique(y_df): {np.unique(y_df)}\n')

        for domain in range(config[dataset]['num_df_domains'], config[dataset]['num_df_domains'] + config[dataset]['num_dp_domains']):
            print(f"Domain: {domain}")

            # Load synthetic data
            x_syn_dom, y_syn_dom, k_syn_dom = get_syn_data(dataset, syn_name, src_class, domain)
            print(f'x_syn_dom.shape: {x_syn_dom.shape} | np.unique(y_syn_dom): {np.unique(y_syn_dom)}')

            # Join Df and synthetic data
            x_df_syn = np.concatenate([x_df, x_syn_dom], axis=0)
            y_df_syn = np.concatenate([y_df, y_syn_dom], axis=0)
            k_df_syn = np.concatenate([k_df, k_syn_dom], axis=0)
            print(f'x_df_syn.shape: {x_df_syn.shape} | np.unique(y_df_syn): {np.unique(y_df_syn)}')

            # Load Dp data
            x_dp_dom, y_dp_dom, k_dp_dom = get_data(dataset, 'dp', src_class, domain)
            print(f'x_dp_dom.shape: {x_dp_dom.shape} | np.unique(y_dp_dom): {np.unique(y_dp_dom)}\n')

            # Train on Df plus synthetic data and test on Dp data
            print('Training on Df plus synthetic data...')
            acc, loss = train_and_test(x_df, y_df, x_dp_dom, y_dp_dom, dataset, num_epochs=num_epochs)
            save_scores(src_class, domain, acc, loss, 'FS_Df_plus_Syn', dataset)
            accs.append(acc)
            print(f'Source class: {src_class} | Domain: {domain} | Accuracy: {acc:.4f} | Loss: {loss:.4f}\n')

    print(f"Mean accuracy: {np.mean(accs):.4f}\n")




compute_TSTRFS_Df_plus_Syn('mobiact_realworld')
