# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd drive/MyDrive/ST/stargan
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/ST/stargan

# %%
dataset = 'realworld_mobiact' # 'realworld' or 'cwru' or 'realworld_mobiact'

# %% [markdown]
# # Pre-trained Networks

# %% [markdown]
# ## Domain Classifiers

# %%
import pickle
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from torch.optim.lr_scheduler import LambdaLR
import matplotlib.pyplot as plt
import os

seed = 2710
np.random.seed(seed)
torch.manual_seed(seed)

class MultiBranchClassifier(nn.Module):
    def __init__(self, num_channels=3, num_domains=4, num_classes=5, num_timesteps=128):
        super(MultiBranchClassifier, self).__init__()
        # Shared layers for all branches
        self.conv1 = nn.Conv1d(num_channels, 16, kernel_size=5, stride=1, padding=2)
        self.bn1 = nn.BatchNorm1d(16)
        self.conv2 = nn.Conv1d(16, 32, kernel_size=5, stride=1, padding=2)
        self.bn2 = nn.BatchNorm1d(32)
        self.conv3 = nn.Conv1d(32, 64, kernel_size=5, stride=1, padding=2)
        self.bn3 = nn.BatchNorm1d(64)
        self.conv4 = nn.Conv1d(64, 128, kernel_size=5, stride=1, padding=2)
        self.bn4 = nn.BatchNorm1d(128)
        self.pool = nn.MaxPool1d(kernel_size=2, stride=2)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.25)
        self.fc_shared = nn.Linear(num_timesteps * 8, 100)

        # Prepare class-specific branches as a single module with conditionally applied outputs
        self.fc_class_branches = nn.Linear(100, 50 * num_classes)
        self.fc_final = nn.Linear(50, num_domains)

    def forward(self, x, class_ids):
        x = self.pool(self.relu(self.bn1(self.conv1(x))))
        x = self.pool(self.relu(self.bn2(self.conv2(x))))
        x = self.pool(self.relu(self.bn3(self.conv3(x))))
        x = self.pool(self.relu(self.bn4(self.conv4(x))))
        x = x.view(x.size(0), -1)
        x = self.dropout(x)
        x = self.relu(self.fc_shared(x))

        # Process all class-specific branches simultaneously
        class_branches = self.fc_class_branches(x).view(x.size(0), -1, 50)
        class_outputs = class_branches[torch.arange(class_branches.size(0)), class_ids]

        # Final class-specific output
        final_outputs = self.fc_final(class_outputs.view(x.size(0), 50))
        return final_outputs.view(x.size(0), -1)


def split_data(x, y, k, test_size=0.2, random_state=seed):
    x_train, x_test, y_train, y_test, k_train, k_test = train_test_split(x, y, k,
                                                                         test_size=test_size,
                                                                         random_state=random_state,
                                                                         stratify=k,
                                                                         shuffle=True)
    return x_train, x_test, y_train, y_test, k_train, k_test


def setup_training(x_train, y_train, k_train, x_test, y_test, k_test, batch_size=64):
    # Convert numpy arrays to torch tensors
    x_train_tensor = torch.tensor(x_train, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train, dtype=torch.long)
    k_train_tensor = torch.tensor(k_train, dtype=torch.long)
    x_test_tensor = torch.tensor(x_test, dtype=torch.float32)
    y_test_tensor = torch.tensor(y_test, dtype=torch.long)
    k_test_tensor = torch.tensor(k_test, dtype=torch.long)

    # Create datasets and loaders
    train_dataset = TensorDataset(x_train_tensor, y_train_tensor, k_train_tensor)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_dataset = TensorDataset(x_test_tensor, y_test_tensor, k_test_tensor)
    test_loader = DataLoader(test_dataset, batch_size=batch_size)

    return train_loader, test_loader


def evaluate_model(model, test_loader, device='cpu'):
    model.eval()
    total_loss = 0
    correct_predictions = 0
    total_predictions = 0

    with torch.no_grad():
        for x_batch, y_batch, k_batch in test_loader:
            x_batch, y_batch, k_batch = x_batch.to(device), y_batch.to(device), k_batch.to(device)
            outputs = model(x_batch, y_batch)
            loss = F.cross_entropy(outputs, k_batch)
            total_loss += loss.item()

            # Assuming outputs are logits and k_batch are the true labels
            _, predicted_labels = torch.max(outputs, 1)
            correct_predictions += (predicted_labels == k_batch).sum().item()
            total_predictions += k_batch.size(0)

    total_loss /= len(test_loader)
    accuracy = correct_predictions / total_predictions

    return total_loss, accuracy


def train_model(model, train_loader, test_loader, optimizer, epochs=300, name='domain_classifier'):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    loss_train = []
    loss_test = []
    accuracy_test = []
    best_loss = np.inf

    # Set up linear learning rate decay
    lambda_lr = lambda epoch: 1 - epoch / epochs
    scheduler = LambdaLR(optimizer, lr_lambda=lambda_lr)

    for epoch in range(epochs):
        model.train()
        total_loss = 0
        for x_batch, y_batch, k_batch in train_loader:
            x_batch, y_batch, k_batch = x_batch.to(device), y_batch.to(device), k_batch.to(device)
            optimizer.zero_grad()
            outputs = model(x_batch, y_batch)
            loss = F.cross_entropy(outputs, k_batch)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        total_loss /= len(train_loader)
        loss_train.append(total_loss)

        # Update learning rate
        scheduler.step()

        test_loss, test_accuracy = evaluate_model(model, test_loader, device=device)
        if test_loss < best_loss:
            best_loss = test_loss
            best_model = model.state_dict().copy()
        loss_test.append(test_loss)
        accuracy_test.append(test_accuracy)

        current_lr = scheduler.get_last_lr()[0]
        print(f"Epoch {epoch + 1}/{epochs} - Train loss: {total_loss:.4f} - Test loss: {test_loss:.4f} - Test accuracy: {test_accuracy:.4f} - LR: {current_lr:.6f}")

    # Save best model
    os.makedirs('pretrained_nets', exist_ok=True)
    if best_model is not None:
        print(f"Saving best model at epoch {np.argmin(loss_test) + 1} and test loss {best_loss:.4f}")
        torch.save(best_model, f"pretrained_nets/{name}.ckpt")
    else:
        print("No best model found, saving current model")
        torch.save(model.state_dict(), f"pretrained_nets/{name}.ckpt")

    return loss_train, loss_test, accuracy_test

# %%
# Train domain classifier on Df

if dataset == 'realworld':
    dataset_name = 'realworld_128_3ch_4cl'
    num_df_domains = 10
    num_dp_domains = 5
    num_classes = 4

elif dataset == 'cwru':
    dataset_name = 'cwru_256_3ch_5cl'
    num_df_domains = 4
    num_dp_domains = 4
    num_classes = 5

elif dataset == 'realworld_mobiact':
    dataset_name = 'realworld_mobiact'
    num_df_domains = 15
    num_dp_domains = 61
    num_classes = 4


with open(f'data/{dataset_name}.pkl', 'rb') as f:
    x, y, k = pickle.load(f)

x = x[k < num_df_domains]
y = y[k < num_df_domains]
k = k[k < num_df_domains]
print(x.shape, y.shape, k.shape)

x_train, x_test, y_train, y_test, k_train, k_test = split_data(x, y, k, test_size=0.2, random_state=seed)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape, k_train.shape, k_test.shape)

model = MultiBranchClassifier(num_domains=num_df_domains, num_classes=num_classes, num_timesteps=x_train.shape[2])

train_loader, test_loader = setup_training(x_train, y_train, k_train, x_test, y_test, k_test)

initial_lr = 0.0001
optimizer = optim.Adam(model.parameters(), lr=initial_lr)

loss_train, loss_test, accuracy_test = train_model(model, train_loader, test_loader, optimizer, epochs=300, name=f'domain_classifier_{dataset}_df')

# Find the best epoch based on the test loss
best_epoch = np.argmin(loss_test)
print(f"Best epoch: {best_epoch + 1} - Test loss: {loss_test[best_epoch]:.4f} - Test accuracy: {accuracy_test[best_epoch]:.4f}")

# Plot the training and test loss displaying the best epoch with a vertical line
plt.figure(figsize=(15, 6))
plt.plot(loss_train, label='Train loss')
plt.plot(loss_test, label='Test loss')
plt.axvline(best_epoch, color='r', linestyle='--')
plt.yscale('log')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# Plot the test accuracy
plt.figure(figsize=(15, 6))
plt.plot(accuracy_test, label='Test accuracy')
plt.axvline(best_epoch, color='r', linestyle='--')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()
# Out:
# (11783, 3, 128) (11783,) (11783,)
# (9426, 3, 128) (2357, 3, 128) (9426,) (2357,) (9426,) (2357,)
# Epoch 1/300 - Train loss: 2.5010 - Test loss: 2.0986 - Test accuracy: 0.3284 - LR: 0.000100
# Epoch 2/300 - Train loss: 1.7211 - Test loss: 1.3729 - Test accuracy: 0.6071 - LR: 0.000099
# Epoch 3/300 - Train loss: 1.1693 - Test loss: 0.9765 - Test accuracy: 0.7463 - LR: 0.000099
# Epoch 4/300 - Train loss: 0.8408 - Test loss: 0.7234 - Test accuracy: 0.8044 - LR: 0.000099
# Epoch 5/300 - Train loss: 0.6041 - Test loss: 0.5247 - Test accuracy: 0.8600 - LR: 0.000098
# Epoch 6/300 - Train loss: 0.4635 - Test loss: 0.4154 - Test accuracy: 0.8854 - LR: 0.000098
# Epoch 7/300 - Train loss: 0.3682 - Test loss: 0.3320 - Test accuracy: 0.9024 - LR: 0.000098
# Epoch 8/300 - Train loss: 0.3022 - Test loss: 0.2960 - Test accuracy: 0.9122 - LR: 0.000097
# Epoch 9/300 - Train loss: 0.2543 - Test loss: 0.2660 - Test accuracy: 0.9266 - LR: 0.000097
# Epoch 10/300 - Train loss: 0.2195 - Test loss: 0.2413 - Test accuracy: 0.9313 - LR: 0.000097
# Epoch 11/300 - Train loss: 0.1916 - Test loss: 0.2117 - Test accuracy: 0.9364 - LR: 0.000096
# Epoch 12/300 - Train loss: 0.1655 - Test loss: 0.1979 - Test accuracy: 0.9419 - LR: 0.000096
# Epoch 13/300 - Train loss: 0.1486 - Test loss: 0.1905 - Test accuracy: 0.9410 - LR: 0.000096
# Epoch 14/300 - Train loss: 0.1306 - Test loss: 0.1670 - Test accuracy: 0.9482 - LR: 0.000095
# Epoch 15/300 - Train loss: 0.1180 - Test loss: 0.1667 - Test accuracy: 0.9491 - LR: 0.000095
# Epoch 16/300 - Train loss: 0.1065 - Test loss: 0.1401 - Test accuracy: 0.9580 - LR: 0.000095
# Epoch 17/300 - Train loss: 0.0942 - Test loss: 0.1372 - Test accuracy: 0.9567 - LR: 0.000094
# Epoch 18/300 - Train loss: 0.0826 - Test loss: 0.1375 - Test accuracy: 0.9576 - LR: 0.000094
# Epoch 19/300 - Train loss: 0.0809 - Test loss: 0.1400 - Test accuracy: 0.9555 - LR: 0.000094
# Epoch 20/300 - Train loss: 0.0708 - Test loss: 0.1139 - Test accuracy: 0.9639 - LR: 0.000093
# Epoch 21/300 - Train loss: 0.0638 - Test loss: 0.1289 - Test accuracy: 0.9584 - LR: 0.000093
# Epoch 22/300 - Train loss: 0.0580 - Test loss: 0.1083 - Test accuracy: 0.9648 - LR: 0.000093
# Epoch 23/300 - Train loss: 0.0535 - Test loss: 0.1107 - Test accuracy: 0.9622 - LR: 0.000092
# Epoch 24/300 - Train loss: 0.0498 - Test loss: 0.1045 - Test accuracy: 0.9631 - LR: 0.000092
# Epoch 25/300 - Train loss: 0.0495 - Test loss: 0.1004 - Test accuracy: 0.9678 - LR: 0.000092
# Epoch 26/300 - Train loss: 0.0417 - Test loss: 0.0982 - Test accuracy: 0.9716 - LR: 0.000091
# Epoch 27/300 - Train loss: 0.0352 - Test loss: 0.0998 - Test accuracy: 0.9686 - LR: 0.000091
# Epoch 28/300 - Train loss: 0.0363 - Test loss: 0.0984 - Test accuracy: 0.9652 - LR: 0.000091
# Epoch 29/300 - Train loss: 0.0342 - Test loss: 0.0971 - Test accuracy: 0.9661 - LR: 0.000090
# Epoch 30/300 - Train loss: 0.0323 - Test loss: 0.0948 - Test accuracy: 0.9673 - LR: 0.000090
# Epoch 31/300 - Train loss: 0.0300 - Test loss: 0.0885 - Test accuracy: 0.9724 - LR: 0.000090
# Epoch 32/300 - Train loss: 0.0271 - Test loss: 0.0856 - Test accuracy: 0.9737 - LR: 0.000089
# Epoch 33/300 - Train loss: 0.0234 - Test loss: 0.1009 - Test accuracy: 0.9673 - LR: 0.000089
# Epoch 34/300 - Train loss: 0.0229 - Test loss: 0.0842 - Test accuracy: 0.9720 - LR: 0.000089
# Epoch 35/300 - Train loss: 0.0192 - Test loss: 0.0792 - Test accuracy: 0.9767 - LR: 0.000088
# Epoch 36/300 - Train loss: 0.0177 - Test loss: 0.0865 - Test accuracy: 0.9720 - LR: 0.000088
# Epoch 37/300 - Train loss: 0.0152 - Test loss: 0.0888 - Test accuracy: 0.9724 - LR: 0.000088
# Epoch 38/300 - Train loss: 0.0196 - Test loss: 0.0795 - Test accuracy: 0.9762 - LR: 0.000087
# Epoch 39/300 - Train loss: 0.0175 - Test loss: 0.0803 - Test accuracy: 0.9741 - LR: 0.000087
# Epoch 40/300 - Train loss: 0.0159 - Test loss: 0.0775 - Test accuracy: 0.9745 - LR: 0.000087
# Epoch 41/300 - Train loss: 0.0168 - Test loss: 0.0771 - Test accuracy: 0.9741 - LR: 0.000086
# Epoch 42/300 - Train loss: 0.0165 - Test loss: 0.0856 - Test accuracy: 0.9733 - LR: 0.000086
# Epoch 43/300 - Train loss: 0.0175 - Test loss: 0.0813 - Test accuracy: 0.9733 - LR: 0.000086
# Epoch 44/300 - Train loss: 0.0114 - Test loss: 0.0774 - Test accuracy: 0.9750 - LR: 0.000085
# Epoch 45/300 - Train loss: 0.0098 - Test loss: 0.0896 - Test accuracy: 0.9737 - LR: 0.000085
# Epoch 46/300 - Train loss: 0.0120 - Test loss: 0.0836 - Test accuracy: 0.9720 - LR: 0.000085
# Epoch 47/300 - Train loss: 0.0106 - Test loss: 0.0763 - Test accuracy: 0.9771 - LR: 0.000084
# Epoch 48/300 - Train loss: 0.0109 - Test loss: 0.0796 - Test accuracy: 0.9745 - LR: 0.000084
# Epoch 49/300 - Train loss: 0.0099 - Test loss: 0.0776 - Test accuracy: 0.9775 - LR: 0.000084
# Epoch 50/300 - Train loss: 0.0097 - Test loss: 0.0874 - Test accuracy: 0.9711 - LR: 0.000083
# Epoch 51/300 - Train loss: 0.0084 - Test loss: 0.0726 - Test accuracy: 0.9775 - LR: 0.000083
# Epoch 52/300 - Train loss: 0.0106 - Test loss: 0.0749 - Test accuracy: 0.9779 - LR: 0.000083
# Epoch 53/300 - Train loss: 0.0090 - Test loss: 0.0730 - Test accuracy: 0.9758 - LR: 0.000082
# Epoch 54/300 - Train loss: 0.0088 - Test loss: 0.0801 - Test accuracy: 0.9775 - LR: 0.000082
# Epoch 55/300 - Train loss: 0.0078 - Test loss: 0.0767 - Test accuracy: 0.9767 - LR: 0.000082
# Epoch 56/300 - Train loss: 0.0074 - Test loss: 0.0754 - Test accuracy: 0.9758 - LR: 0.000081
# Epoch 57/300 - Train loss: 0.0057 - Test loss: 0.0726 - Test accuracy: 0.9788 - LR: 0.000081
# Epoch 58/300 - Train loss: 0.0097 - Test loss: 0.0757 - Test accuracy: 0.9767 - LR: 0.000081
# Epoch 59/300 - Train loss: 0.0048 - Test loss: 0.0791 - Test accuracy: 0.9745 - LR: 0.000080
# Epoch 60/300 - Train loss: 0.0076 - Test loss: 0.0813 - Test accuracy: 0.9741 - LR: 0.000080
# Epoch 61/300 - Train loss: 0.0078 - Test loss: 0.0820 - Test accuracy: 0.9788 - LR: 0.000080
# Epoch 62/300 - Train loss: 0.0088 - Test loss: 0.0873 - Test accuracy: 0.9750 - LR: 0.000079
# Epoch 63/300 - Train loss: 0.0082 - Test loss: 0.0811 - Test accuracy: 0.9750 - LR: 0.000079
# Epoch 64/300 - Train loss: 0.0072 - Test loss: 0.0871 - Test accuracy: 0.9762 - LR: 0.000079
# Epoch 65/300 - Train loss: 0.0070 - Test loss: 0.0833 - Test accuracy: 0.9767 - LR: 0.000078
# Epoch 66/300 - Train loss: 0.0060 - Test loss: 0.0757 - Test accuracy: 0.9762 - LR: 0.000078
# Epoch 67/300 - Train loss: 0.0047 - Test loss: 0.0737 - Test accuracy: 0.9784 - LR: 0.000078
# Epoch 68/300 - Train loss: 0.0067 - Test loss: 0.0769 - Test accuracy: 0.9771 - LR: 0.000077
# Epoch 69/300 - Train loss: 0.0083 - Test loss: 0.0856 - Test accuracy: 0.9771 - LR: 0.000077
# Epoch 70/300 - Train loss: 0.0059 - Test loss: 0.0751 - Test accuracy: 0.9762 - LR: 0.000077
# Epoch 71/300 - Train loss: 0.0046 - Test loss: 0.0765 - Test accuracy: 0.9771 - LR: 0.000076
# Epoch 72/300 - Train loss: 0.0090 - Test loss: 0.0668 - Test accuracy: 0.9801 - LR: 0.000076
# Epoch 73/300 - Train loss: 0.0029 - Test loss: 0.0718 - Test accuracy: 0.9779 - LR: 0.000076
# Epoch 74/300 - Train loss: 0.0038 - Test loss: 0.0733 - Test accuracy: 0.9788 - LR: 0.000075
# Epoch 75/300 - Train loss: 0.0031 - Test loss: 0.0751 - Test accuracy: 0.9771 - LR: 0.000075
# Epoch 76/300 - Train loss: 0.0027 - Test loss: 0.0741 - Test accuracy: 0.9775 - LR: 0.000075
# Epoch 77/300 - Train loss: 0.0026 - Test loss: 0.0724 - Test accuracy: 0.9801 - LR: 0.000074
# Epoch 78/300 - Train loss: 0.0035 - Test loss: 0.0751 - Test accuracy: 0.9767 - LR: 0.000074
# Epoch 79/300 - Train loss: 0.0056 - Test loss: 0.0750 - Test accuracy: 0.9796 - LR: 0.000074
# Epoch 80/300 - Train loss: 0.0027 - Test loss: 0.0700 - Test accuracy: 0.9818 - LR: 0.000073
# Epoch 81/300 - Train loss: 0.0035 - Test loss: 0.0732 - Test accuracy: 0.9784 - LR: 0.000073
# Epoch 82/300 - Train loss: 0.0050 - Test loss: 0.0845 - Test accuracy: 0.9720 - LR: 0.000073
# Epoch 83/300 - Train loss: 0.0036 - Test loss: 0.0803 - Test accuracy: 0.9775 - LR: 0.000072
# Epoch 84/300 - Train loss: 0.0050 - Test loss: 0.0724 - Test accuracy: 0.9801 - LR: 0.000072
# Epoch 85/300 - Train loss: 0.0054 - Test loss: 0.0861 - Test accuracy: 0.9737 - LR: 0.000072
# Epoch 86/300 - Train loss: 0.0027 - Test loss: 0.0707 - Test accuracy: 0.9822 - LR: 0.000071
# Epoch 87/300 - Train loss: 0.0055 - Test loss: 0.0834 - Test accuracy: 0.9762 - LR: 0.000071
# Epoch 88/300 - Train loss: 0.0030 - Test loss: 0.0821 - Test accuracy: 0.9762 - LR: 0.000071
# Epoch 89/300 - Train loss: 0.0035 - Test loss: 0.0859 - Test accuracy: 0.9767 - LR: 0.000070
# Epoch 90/300 - Train loss: 0.0028 - Test loss: 0.0706 - Test accuracy: 0.9805 - LR: 0.000070
# Epoch 91/300 - Train loss: 0.0025 - Test loss: 0.0714 - Test accuracy: 0.9822 - LR: 0.000070
# Epoch 92/300 - Train loss: 0.0031 - Test loss: 0.0753 - Test accuracy: 0.9788 - LR: 0.000069
# Epoch 93/300 - Train loss: 0.0021 - Test loss: 0.0677 - Test accuracy: 0.9822 - LR: 0.000069
# Epoch 94/300 - Train loss: 0.0025 - Test loss: 0.0711 - Test accuracy: 0.9801 - LR: 0.000069
# Epoch 95/300 - Train loss: 0.0019 - Test loss: 0.0713 - Test accuracy: 0.9796 - LR: 0.000068
# Epoch 96/300 - Train loss: 0.0046 - Test loss: 0.0894 - Test accuracy: 0.9754 - LR: 0.000068
# Epoch 97/300 - Train loss: 0.0038 - Test loss: 0.0834 - Test accuracy: 0.9750 - LR: 0.000068
# Epoch 98/300 - Train loss: 0.0040 - Test loss: 0.0703 - Test accuracy: 0.9792 - LR: 0.000067
# Epoch 99/300 - Train loss: 0.0029 - Test loss: 0.0733 - Test accuracy: 0.9805 - LR: 0.000067
# Epoch 100/300 - Train loss: 0.0026 - Test loss: 0.0806 - Test accuracy: 0.9801 - LR: 0.000067
# Epoch 101/300 - Train loss: 0.0023 - Test loss: 0.0700 - Test accuracy: 0.9796 - LR: 0.000066
# Epoch 102/300 - Train loss: 0.0025 - Test loss: 0.0728 - Test accuracy: 0.9788 - LR: 0.000066
# Epoch 103/300 - Train loss: 0.0028 - Test loss: 0.0828 - Test accuracy: 0.9784 - LR: 0.000066
# Epoch 104/300 - Train loss: 0.0046 - Test loss: 0.0676 - Test accuracy: 0.9843 - LR: 0.000065
# Epoch 105/300 - Train loss: 0.0046 - Test loss: 0.0759 - Test accuracy: 0.9775 - LR: 0.000065
# Epoch 106/300 - Train loss: 0.0026 - Test loss: 0.0785 - Test accuracy: 0.9788 - LR: 0.000065
# Epoch 107/300 - Train loss: 0.0017 - Test loss: 0.0663 - Test accuracy: 0.9805 - LR: 0.000064
# Epoch 108/300 - Train loss: 0.0010 - Test loss: 0.0673 - Test accuracy: 0.9822 - LR: 0.000064
# Epoch 109/300 - Train loss: 0.0015 - Test loss: 0.0682 - Test accuracy: 0.9813 - LR: 0.000064
# Epoch 110/300 - Train loss: 0.0014 - Test loss: 0.0885 - Test accuracy: 0.9754 - LR: 0.000063
# Epoch 111/300 - Train loss: 0.0038 - Test loss: 0.0811 - Test accuracy: 0.9796 - LR: 0.000063
# Epoch 112/300 - Train loss: 0.0029 - Test loss: 0.0721 - Test accuracy: 0.9822 - LR: 0.000063
# Epoch 113/300 - Train loss: 0.0026 - Test loss: 0.1175 - Test accuracy: 0.9673 - LR: 0.000062
# Epoch 114/300 - Train loss: 0.0042 - Test loss: 0.0702 - Test accuracy: 0.9822 - LR: 0.000062
# Epoch 115/300 - Train loss: 0.0010 - Test loss: 0.0721 - Test accuracy: 0.9784 - LR: 0.000062
# Epoch 116/300 - Train loss: 0.0056 - Test loss: 0.0726 - Test accuracy: 0.9813 - LR: 0.000061
# Epoch 117/300 - Train loss: 0.0046 - Test loss: 0.0730 - Test accuracy: 0.9805 - LR: 0.000061
# Epoch 118/300 - Train loss: 0.0026 - Test loss: 0.0828 - Test accuracy: 0.9779 - LR: 0.000061
# Epoch 119/300 - Train loss: 0.0019 - Test loss: 0.0800 - Test accuracy: 0.9784 - LR: 0.000060
# Epoch 120/300 - Train loss: 0.0026 - Test loss: 0.0675 - Test accuracy: 0.9826 - LR: 0.000060
# Epoch 121/300 - Train loss: 0.0011 - Test loss: 0.0734 - Test accuracy: 0.9801 - LR: 0.000060
# Epoch 122/300 - Train loss: 0.0014 - Test loss: 0.0680 - Test accuracy: 0.9796 - LR: 0.000059
# Epoch 123/300 - Train loss: 0.0013 - Test loss: 0.0690 - Test accuracy: 0.9818 - LR: 0.000059
# Epoch 124/300 - Train loss: 0.0029 - Test loss: 0.0692 - Test accuracy: 0.9818 - LR: 0.000059
# Epoch 125/300 - Train loss: 0.0010 - Test loss: 0.0657 - Test accuracy: 0.9818 - LR: 0.000058
# Epoch 126/300 - Train loss: 0.0035 - Test loss: 0.0800 - Test accuracy: 0.9775 - LR: 0.000058
# Epoch 127/300 - Train loss: 0.0020 - Test loss: 0.0728 - Test accuracy: 0.9805 - LR: 0.000058
# Epoch 128/300 - Train loss: 0.0027 - Test loss: 0.0713 - Test accuracy: 0.9818 - LR: 0.000057
# Epoch 129/300 - Train loss: 0.0025 - Test loss: 0.0691 - Test accuracy: 0.9826 - LR: 0.000057
# Epoch 130/300 - Train loss: 0.0012 - Test loss: 0.0708 - Test accuracy: 0.9818 - LR: 0.000057
# Epoch 131/300 - Train loss: 0.0011 - Test loss: 0.0703 - Test accuracy: 0.9805 - LR: 0.000056
# Epoch 132/300 - Train loss: 0.0007 - Test loss: 0.0636 - Test accuracy: 0.9813 - LR: 0.000056
# Epoch 133/300 - Train loss: 0.0011 - Test loss: 0.0703 - Test accuracy: 0.9818 - LR: 0.000056
# Epoch 134/300 - Train loss: 0.0016 - Test loss: 0.0762 - Test accuracy: 0.9792 - LR: 0.000055
# Epoch 135/300 - Train loss: 0.0014 - Test loss: 0.0700 - Test accuracy: 0.9818 - LR: 0.000055
# Epoch 136/300 - Train loss: 0.0009 - Test loss: 0.0670 - Test accuracy: 0.9809 - LR: 0.000055
# Epoch 137/300 - Train loss: 0.0026 - Test loss: 0.0657 - Test accuracy: 0.9839 - LR: 0.000054
# Epoch 138/300 - Train loss: 0.0024 - Test loss: 0.0735 - Test accuracy: 0.9801 - LR: 0.000054
# Epoch 139/300 - Train loss: 0.0034 - Test loss: 0.0684 - Test accuracy: 0.9826 - LR: 0.000054
# Epoch 140/300 - Train loss: 0.0021 - Test loss: 0.0652 - Test accuracy: 0.9835 - LR: 0.000053
# Epoch 141/300 - Train loss: 0.0024 - Test loss: 0.0722 - Test accuracy: 0.9805 - LR: 0.000053
# Epoch 142/300 - Train loss: 0.0017 - Test loss: 0.0710 - Test accuracy: 0.9813 - LR: 0.000053
# Epoch 143/300 - Train loss: 0.0016 - Test loss: 0.0666 - Test accuracy: 0.9818 - LR: 0.000052
# Epoch 144/300 - Train loss: 0.0009 - Test loss: 0.0636 - Test accuracy: 0.9826 - LR: 0.000052
# Epoch 145/300 - Train loss: 0.0012 - Test loss: 0.0717 - Test accuracy: 0.9813 - LR: 0.000052
# Epoch 146/300 - Train loss: 0.0019 - Test loss: 0.0692 - Test accuracy: 0.9818 - LR: 0.000051
# Epoch 147/300 - Train loss: 0.0008 - Test loss: 0.0646 - Test accuracy: 0.9839 - LR: 0.000051
# Epoch 148/300 - Train loss: 0.0008 - Test loss: 0.0637 - Test accuracy: 0.9839 - LR: 0.000051
# Epoch 149/300 - Train loss: 0.0030 - Test loss: 0.0664 - Test accuracy: 0.9818 - LR: 0.000050
# Epoch 150/300 - Train loss: 0.0011 - Test loss: 0.0747 - Test accuracy: 0.9813 - LR: 0.000050
# Epoch 151/300 - Train loss: 0.0014 - Test loss: 0.0676 - Test accuracy: 0.9835 - LR: 0.000050
# Epoch 152/300 - Train loss: 0.0011 - Test loss: 0.0696 - Test accuracy: 0.9830 - LR: 0.000049
# Epoch 153/300 - Train loss: 0.0013 - Test loss: 0.0677 - Test accuracy: 0.9847 - LR: 0.000049
# Epoch 154/300 - Train loss: 0.0010 - Test loss: 0.0682 - Test accuracy: 0.9835 - LR: 0.000049
# Epoch 155/300 - Train loss: 0.0007 - Test loss: 0.0675 - Test accuracy: 0.9839 - LR: 0.000048
# Epoch 156/300 - Train loss: 0.0005 - Test loss: 0.0675 - Test accuracy: 0.9847 - LR: 0.000048
# Epoch 157/300 - Train loss: 0.0021 - Test loss: 0.0715 - Test accuracy: 0.9813 - LR: 0.000048
# Epoch 158/300 - Train loss: 0.0010 - Test loss: 0.0735 - Test accuracy: 0.9830 - LR: 0.000047
# Epoch 159/300 - Train loss: 0.0006 - Test loss: 0.0704 - Test accuracy: 0.9796 - LR: 0.000047
# Epoch 160/300 - Train loss: 0.0009 - Test loss: 0.0669 - Test accuracy: 0.9826 - LR: 0.000047
# Epoch 161/300 - Train loss: 0.0004 - Test loss: 0.0688 - Test accuracy: 0.9852 - LR: 0.000046
# Epoch 162/300 - Train loss: 0.0011 - Test loss: 0.0753 - Test accuracy: 0.9822 - LR: 0.000046
# Epoch 163/300 - Train loss: 0.0013 - Test loss: 0.0679 - Test accuracy: 0.9843 - LR: 0.000046
# Epoch 164/300 - Train loss: 0.0004 - Test loss: 0.0711 - Test accuracy: 0.9818 - LR: 0.000045
# Epoch 165/300 - Train loss: 0.0011 - Test loss: 0.0802 - Test accuracy: 0.9805 - LR: 0.000045
# Epoch 166/300 - Train loss: 0.0014 - Test loss: 0.0737 - Test accuracy: 0.9826 - LR: 0.000045
# Epoch 167/300 - Train loss: 0.0019 - Test loss: 0.0763 - Test accuracy: 0.9788 - LR: 0.000044
# Epoch 168/300 - Train loss: 0.0014 - Test loss: 0.0737 - Test accuracy: 0.9818 - LR: 0.000044
# Epoch 169/300 - Train loss: 0.0009 - Test loss: 0.0724 - Test accuracy: 0.9835 - LR: 0.000044
# Epoch 170/300 - Train loss: 0.0009 - Test loss: 0.0667 - Test accuracy: 0.9843 - LR: 0.000043
# Epoch 171/300 - Train loss: 0.0011 - Test loss: 0.0666 - Test accuracy: 0.9852 - LR: 0.000043
# Epoch 172/300 - Train loss: 0.0021 - Test loss: 0.0776 - Test accuracy: 0.9813 - LR: 0.000043
# Epoch 173/300 - Train loss: 0.0021 - Test loss: 0.0940 - Test accuracy: 0.9750 - LR: 0.000042
# Epoch 174/300 - Train loss: 0.0009 - Test loss: 0.0746 - Test accuracy: 0.9835 - LR: 0.000042
# Epoch 175/300 - Train loss: 0.0009 - Test loss: 0.0689 - Test accuracy: 0.9818 - LR: 0.000042
# Epoch 176/300 - Train loss: 0.0007 - Test loss: 0.0687 - Test accuracy: 0.9826 - LR: 0.000041
# Epoch 177/300 - Train loss: 0.0018 - Test loss: 0.0694 - Test accuracy: 0.9830 - LR: 0.000041
# Epoch 178/300 - Train loss: 0.0018 - Test loss: 0.0664 - Test accuracy: 0.9835 - LR: 0.000041
# Epoch 179/300 - Train loss: 0.0007 - Test loss: 0.0688 - Test accuracy: 0.9826 - LR: 0.000040
# Epoch 180/300 - Train loss: 0.0007 - Test loss: 0.0677 - Test accuracy: 0.9822 - LR: 0.000040
# Epoch 181/300 - Train loss: 0.0005 - Test loss: 0.0679 - Test accuracy: 0.9835 - LR: 0.000040
# Epoch 182/300 - Train loss: 0.0004 - Test loss: 0.0699 - Test accuracy: 0.9835 - LR: 0.000039
# Epoch 183/300 - Train loss: 0.0005 - Test loss: 0.0683 - Test accuracy: 0.9809 - LR: 0.000039
# Epoch 184/300 - Train loss: 0.0006 - Test loss: 0.0715 - Test accuracy: 0.9813 - LR: 0.000039
# Epoch 185/300 - Train loss: 0.0006 - Test loss: 0.0664 - Test accuracy: 0.9830 - LR: 0.000038
# Epoch 186/300 - Train loss: 0.0006 - Test loss: 0.0666 - Test accuracy: 0.9822 - LR: 0.000038
# Epoch 187/300 - Train loss: 0.0004 - Test loss: 0.0687 - Test accuracy: 0.9822 - LR: 0.000038
# Epoch 188/300 - Train loss: 0.0003 - Test loss: 0.0658 - Test accuracy: 0.9839 - LR: 0.000037
# Epoch 189/300 - Train loss: 0.0014 - Test loss: 0.0859 - Test accuracy: 0.9775 - LR: 0.000037
# Epoch 190/300 - Train loss: 0.0009 - Test loss: 0.0703 - Test accuracy: 0.9830 - LR: 0.000037
# Epoch 191/300 - Train loss: 0.0011 - Test loss: 0.0686 - Test accuracy: 0.9835 - LR: 0.000036
# Epoch 192/300 - Train loss: 0.0005 - Test loss: 0.0656 - Test accuracy: 0.9843 - LR: 0.000036
# Epoch 193/300 - Train loss: 0.0004 - Test loss: 0.0629 - Test accuracy: 0.9839 - LR: 0.000036
# Epoch 194/300 - Train loss: 0.0006 - Test loss: 0.0728 - Test accuracy: 0.9822 - LR: 0.000035
# Epoch 195/300 - Train loss: 0.0013 - Test loss: 0.0676 - Test accuracy: 0.9830 - LR: 0.000035
# Epoch 196/300 - Train loss: 0.0007 - Test loss: 0.0693 - Test accuracy: 0.9813 - LR: 0.000035
# Epoch 197/300 - Train loss: 0.0004 - Test loss: 0.0736 - Test accuracy: 0.9830 - LR: 0.000034
# Epoch 198/300 - Train loss: 0.0005 - Test loss: 0.0683 - Test accuracy: 0.9839 - LR: 0.000034
# Epoch 199/300 - Train loss: 0.0006 - Test loss: 0.0837 - Test accuracy: 0.9809 - LR: 0.000034
# Epoch 200/300 - Train loss: 0.0008 - Test loss: 0.0771 - Test accuracy: 0.9826 - LR: 0.000033
# Epoch 201/300 - Train loss: 0.0004 - Test loss: 0.0737 - Test accuracy: 0.9830 - LR: 0.000033
# Epoch 202/300 - Train loss: 0.0007 - Test loss: 0.0756 - Test accuracy: 0.9809 - LR: 0.000033
# Epoch 203/300 - Train loss: 0.0006 - Test loss: 0.0652 - Test accuracy: 0.9830 - LR: 0.000032
# Epoch 204/300 - Train loss: 0.0010 - Test loss: 0.0780 - Test accuracy: 0.9792 - LR: 0.000032
# Epoch 205/300 - Train loss: 0.0017 - Test loss: 0.0785 - Test accuracy: 0.9818 - LR: 0.000032
# Epoch 206/300 - Train loss: 0.0005 - Test loss: 0.0765 - Test accuracy: 0.9813 - LR: 0.000031
# Epoch 207/300 - Train loss: 0.0004 - Test loss: 0.0689 - Test accuracy: 0.9826 - LR: 0.000031
# Epoch 208/300 - Train loss: 0.0005 - Test loss: 0.0708 - Test accuracy: 0.9830 - LR: 0.000031
# Epoch 209/300 - Train loss: 0.0004 - Test loss: 0.0716 - Test accuracy: 0.9830 - LR: 0.000030
# Epoch 210/300 - Train loss: 0.0004 - Test loss: 0.0687 - Test accuracy: 0.9835 - LR: 0.000030
# Epoch 211/300 - Train loss: 0.0003 - Test loss: 0.0677 - Test accuracy: 0.9826 - LR: 0.000030
# Epoch 212/300 - Train loss: 0.0007 - Test loss: 0.0676 - Test accuracy: 0.9843 - LR: 0.000029
# Epoch 213/300 - Train loss: 0.0009 - Test loss: 0.0703 - Test accuracy: 0.9826 - LR: 0.000029
# Epoch 214/300 - Train loss: 0.0008 - Test loss: 0.0706 - Test accuracy: 0.9826 - LR: 0.000029
# Epoch 215/300 - Train loss: 0.0007 - Test loss: 0.0660 - Test accuracy: 0.9830 - LR: 0.000028
# Epoch 216/300 - Train loss: 0.0011 - Test loss: 0.0739 - Test accuracy: 0.9809 - LR: 0.000028
# Epoch 217/300 - Train loss: 0.0004 - Test loss: 0.0682 - Test accuracy: 0.9843 - LR: 0.000028
# Epoch 218/300 - Train loss: 0.0006 - Test loss: 0.0707 - Test accuracy: 0.9813 - LR: 0.000027
# Epoch 219/300 - Train loss: 0.0004 - Test loss: 0.0664 - Test accuracy: 0.9847 - LR: 0.000027
# Epoch 220/300 - Train loss: 0.0004 - Test loss: 0.0642 - Test accuracy: 0.9830 - LR: 0.000027
# Epoch 221/300 - Train loss: 0.0004 - Test loss: 0.0645 - Test accuracy: 0.9826 - LR: 0.000026
# Epoch 222/300 - Train loss: 0.0013 - Test loss: 0.0714 - Test accuracy: 0.9818 - LR: 0.000026
# Epoch 223/300 - Train loss: 0.0007 - Test loss: 0.0735 - Test accuracy: 0.9822 - LR: 0.000026
# Epoch 224/300 - Train loss: 0.0016 - Test loss: 0.0676 - Test accuracy: 0.9843 - LR: 0.000025
# Epoch 225/300 - Train loss: 0.0006 - Test loss: 0.0695 - Test accuracy: 0.9835 - LR: 0.000025
# Epoch 226/300 - Train loss: 0.0005 - Test loss: 0.0701 - Test accuracy: 0.9839 - LR: 0.000025
# Epoch 227/300 - Train loss: 0.0025 - Test loss: 0.0686 - Test accuracy: 0.9843 - LR: 0.000024
# Epoch 228/300 - Train loss: 0.0010 - Test loss: 0.0685 - Test accuracy: 0.9864 - LR: 0.000024
# Epoch 229/300 - Train loss: 0.0004 - Test loss: 0.0661 - Test accuracy: 0.9839 - LR: 0.000024
# Epoch 230/300 - Train loss: 0.0004 - Test loss: 0.0675 - Test accuracy: 0.9839 - LR: 0.000023
# Epoch 231/300 - Train loss: 0.0025 - Test loss: 0.0719 - Test accuracy: 0.9839 - LR: 0.000023
# Epoch 232/300 - Train loss: 0.0007 - Test loss: 0.0702 - Test accuracy: 0.9847 - LR: 0.000023
# Epoch 233/300 - Train loss: 0.0003 - Test loss: 0.0701 - Test accuracy: 0.9860 - LR: 0.000022
# Epoch 234/300 - Train loss: 0.0002 - Test loss: 0.0658 - Test accuracy: 0.9852 - LR: 0.000022
# Epoch 235/300 - Train loss: 0.0004 - Test loss: 0.0698 - Test accuracy: 0.9856 - LR: 0.000022
# Epoch 236/300 - Train loss: 0.0002 - Test loss: 0.0686 - Test accuracy: 0.9856 - LR: 0.000021
# Epoch 237/300 - Train loss: 0.0006 - Test loss: 0.0681 - Test accuracy: 0.9843 - LR: 0.000021
# Epoch 238/300 - Train loss: 0.0002 - Test loss: 0.0671 - Test accuracy: 0.9864 - LR: 0.000021
# Epoch 239/300 - Train loss: 0.0004 - Test loss: 0.0662 - Test accuracy: 0.9873 - LR: 0.000020
# Epoch 240/300 - Train loss: 0.0006 - Test loss: 0.0684 - Test accuracy: 0.9839 - LR: 0.000020
# Epoch 241/300 - Train loss: 0.0004 - Test loss: 0.0658 - Test accuracy: 0.9839 - LR: 0.000020
# Epoch 242/300 - Train loss: 0.0004 - Test loss: 0.0647 - Test accuracy: 0.9843 - LR: 0.000019
# Epoch 243/300 - Train loss: 0.0002 - Test loss: 0.0635 - Test accuracy: 0.9860 - LR: 0.000019
# Epoch 244/300 - Train loss: 0.0002 - Test loss: 0.0648 - Test accuracy: 0.9847 - LR: 0.000019
# Epoch 245/300 - Train loss: 0.0004 - Test loss: 0.0676 - Test accuracy: 0.9843 - LR: 0.000018
# Epoch 246/300 - Train loss: 0.0002 - Test loss: 0.0659 - Test accuracy: 0.9856 - LR: 0.000018
# Epoch 247/300 - Train loss: 0.0004 - Test loss: 0.0679 - Test accuracy: 0.9835 - LR: 0.000018
# Epoch 248/300 - Train loss: 0.0006 - Test loss: 0.0683 - Test accuracy: 0.9839 - LR: 0.000017
# Epoch 249/300 - Train loss: 0.0003 - Test loss: 0.0663 - Test accuracy: 0.9860 - LR: 0.000017
# Epoch 250/300 - Train loss: 0.0003 - Test loss: 0.0674 - Test accuracy: 0.9839 - LR: 0.000017
# Epoch 251/300 - Train loss: 0.0011 - Test loss: 0.0685 - Test accuracy: 0.9835 - LR: 0.000016
# Epoch 252/300 - Train loss: 0.0006 - Test loss: 0.0688 - Test accuracy: 0.9839 - LR: 0.000016
# Epoch 253/300 - Train loss: 0.0002 - Test loss: 0.0669 - Test accuracy: 0.9847 - LR: 0.000016
# Epoch 254/300 - Train loss: 0.0003 - Test loss: 0.0664 - Test accuracy: 0.9847 - LR: 0.000015
# Epoch 255/300 - Train loss: 0.0003 - Test loss: 0.0659 - Test accuracy: 0.9843 - LR: 0.000015
# Epoch 256/300 - Train loss: 0.0002 - Test loss: 0.0656 - Test accuracy: 0.9860 - LR: 0.000015
# Epoch 257/300 - Train loss: 0.0002 - Test loss: 0.0658 - Test accuracy: 0.9856 - LR: 0.000014
# Epoch 258/300 - Train loss: 0.0002 - Test loss: 0.0657 - Test accuracy: 0.9852 - LR: 0.000014
# Epoch 259/300 - Train loss: 0.0003 - Test loss: 0.0693 - Test accuracy: 0.9852 - LR: 0.000014
# Epoch 260/300 - Train loss: 0.0002 - Test loss: 0.0670 - Test accuracy: 0.9864 - LR: 0.000013
# Epoch 261/300 - Train loss: 0.0004 - Test loss: 0.0704 - Test accuracy: 0.9830 - LR: 0.000013
# Epoch 262/300 - Train loss: 0.0002 - Test loss: 0.0656 - Test accuracy: 0.9847 - LR: 0.000013
# Epoch 263/300 - Train loss: 0.0003 - Test loss: 0.0639 - Test accuracy: 0.9843 - LR: 0.000012
# Epoch 264/300 - Train loss: 0.0003 - Test loss: 0.0662 - Test accuracy: 0.9847 - LR: 0.000012
# Epoch 265/300 - Train loss: 0.0004 - Test loss: 0.0675 - Test accuracy: 0.9826 - LR: 0.000012
# Epoch 266/300 - Train loss: 0.0003 - Test loss: 0.0663 - Test accuracy: 0.9843 - LR: 0.000011
# Epoch 267/300 - Train loss: 0.0006 - Test loss: 0.0714 - Test accuracy: 0.9826 - LR: 0.000011
# Epoch 268/300 - Train loss: 0.0007 - Test loss: 0.0673 - Test accuracy: 0.9847 - LR: 0.000011
# Epoch 269/300 - Train loss: 0.0004 - Test loss: 0.0674 - Test accuracy: 0.9860 - LR: 0.000010
# Epoch 270/300 - Train loss: 0.0003 - Test loss: 0.0663 - Test accuracy: 0.9856 - LR: 0.000010
# Epoch 271/300 - Train loss: 0.0004 - Test loss: 0.0697 - Test accuracy: 0.9847 - LR: 0.000010
# Epoch 272/300 - Train loss: 0.0014 - Test loss: 0.0683 - Test accuracy: 0.9847 - LR: 0.000009
# Epoch 273/300 - Train loss: 0.0006 - Test loss: 0.0681 - Test accuracy: 0.9852 - LR: 0.000009
# Epoch 274/300 - Train loss: 0.0002 - Test loss: 0.0667 - Test accuracy: 0.9843 - LR: 0.000009
# Epoch 275/300 - Train loss: 0.0002 - Test loss: 0.0664 - Test accuracy: 0.9852 - LR: 0.000008
# Epoch 276/300 - Train loss: 0.0004 - Test loss: 0.0656 - Test accuracy: 0.9847 - LR: 0.000008
# Epoch 277/300 - Train loss: 0.0003 - Test loss: 0.0675 - Test accuracy: 0.9843 - LR: 0.000008
# Epoch 278/300 - Train loss: 0.0004 - Test loss: 0.0685 - Test accuracy: 0.9839 - LR: 0.000007
# Epoch 279/300 - Train loss: 0.0002 - Test loss: 0.0683 - Test accuracy: 0.9830 - LR: 0.000007
# Epoch 280/300 - Train loss: 0.0008 - Test loss: 0.0677 - Test accuracy: 0.9839 - LR: 0.000007
# Epoch 281/300 - Train loss: 0.0005 - Test loss: 0.0668 - Test accuracy: 0.9839 - LR: 0.000006
# Epoch 282/300 - Train loss: 0.0003 - Test loss: 0.0661 - Test accuracy: 0.9856 - LR: 0.000006
# Epoch 283/300 - Train loss: 0.0007 - Test loss: 0.0681 - Test accuracy: 0.9856 - LR: 0.000006
# Epoch 284/300 - Train loss: 0.0003 - Test loss: 0.0653 - Test accuracy: 0.9852 - LR: 0.000005
# Epoch 285/300 - Train loss: 0.0002 - Test loss: 0.0666 - Test accuracy: 0.9843 - LR: 0.000005
# Epoch 286/300 - Train loss: 0.0003 - Test loss: 0.0660 - Test accuracy: 0.9852 - LR: 0.000005
# Epoch 287/300 - Train loss: 0.0003 - Test loss: 0.0654 - Test accuracy: 0.9856 - LR: 0.000004
# Epoch 288/300 - Train loss: 0.0003 - Test loss: 0.0657 - Test accuracy: 0.9852 - LR: 0.000004
# Epoch 289/300 - Train loss: 0.0007 - Test loss: 0.0640 - Test accuracy: 0.9852 - LR: 0.000004
# Epoch 290/300 - Train loss: 0.0002 - Test loss: 0.0648 - Test accuracy: 0.9860 - LR: 0.000003
# Epoch 291/300 - Train loss: 0.0001 - Test loss: 0.0653 - Test accuracy: 0.9847 - LR: 0.000003
# Epoch 292/300 - Train loss: 0.0020 - Test loss: 0.0651 - Test accuracy: 0.9856 - LR: 0.000003
# Epoch 293/300 - Train loss: 0.0002 - Test loss: 0.0665 - Test accuracy: 0.9864 - LR: 0.000002
# Epoch 294/300 - Train loss: 0.0003 - Test loss: 0.0657 - Test accuracy: 0.9864 - LR: 0.000002
# Epoch 295/300 - Train loss: 0.0003 - Test loss: 0.0657 - Test accuracy: 0.9860 - LR: 0.000002
# Epoch 296/300 - Train loss: 0.0003 - Test loss: 0.0646 - Test accuracy: 0.9856 - LR: 0.000001
# Epoch 297/300 - Train loss: 0.0005 - Test loss: 0.0645 - Test accuracy: 0.9856 - LR: 0.000001
# Epoch 298/300 - Train loss: 0.0011 - Test loss: 0.0661 - Test accuracy: 0.9847 - LR: 0.000001
# Epoch 299/300 - Train loss: 0.0003 - Test loss: 0.0673 - Test accuracy: 0.9856 - LR: 0.000000
# Epoch 300/300 - Train loss: 0.0003 - Test loss: 0.0654 - Test accuracy: 0.9856 - LR: 0.000000
# Saving best model at epoch 193 and test loss 0.0629
# Best epoch: 193 - Test loss: 0.0629 - Test accuracy: 0.9839

# %%
# Train domain classifier on Dp

with open(f'data/{dataset_name}.pkl', 'rb') as f:
    x, y, k = pickle.load(f)

with open(f'data/{dataset_name}_fs.pkl', 'rb') as f:
    fs = pickle.load(f)

x = x[fs == 0]
y = y[fs == 0]
k = k[fs == 0]
x = x[k >= num_df_domains]
y = y[k >= num_df_domains]
k = k[k >= num_df_domains] - num_df_domains
print(x.shape, y.shape, k.shape)

x_train, x_test, y_train, y_test, k_train, k_test = split_data(x, y, k, test_size=0.2, random_state=seed)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape, k_train.shape, k_test.shape)

model = MultiBranchClassifier(num_domains=num_dp_domains, num_classes=num_classes, num_timesteps=x_train.shape[2])

train_loader, test_loader = setup_training(x_train, y_train, k_train, x_test, y_test, k_test)

loss_fn = nn.CrossEntropyLoss()

initial_lr = 0.0001
optimizer = optim.Adam(model.parameters(), lr=initial_lr)

loss_train, loss_test, accuracy_test = train_model(model, train_loader, test_loader, optimizer, epochs=300, name=f'domain_classifier_{dataset}_dp')

# Find the best epoch based on the test loss
best_epoch = np.argmin(loss_test)
print(f"Best epoch: {best_epoch + 1} - Test loss: {loss_test[best_epoch]:.4f} - Test accuracy: {accuracy_test[best_epoch]:.4f}")

# Plot the training and test loss displaying the best epoch with a vertical line
plt.figure(figsize=(15, 6))
plt.plot(loss_train, label='Train loss')
plt.plot(loss_test, label='Test loss')
plt.axvline(best_epoch, color='r', linestyle='--')
plt.yscale('log')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# Plot the test accuracy
plt.figure(figsize=(15, 6))
plt.plot(accuracy_test, label='Test accuracy')
plt.axvline(best_epoch, color='r', linestyle='--')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()
# Out:
# (9596, 3, 128) (9596,) (9596,)
# (7676, 3, 128) (1920, 3, 128) (7676,) (1920,) (7676,) (1920,)
# Epoch 1/300 - Train loss: 3.9844 - Test loss: 3.7598 - Test accuracy: 0.0797 - LR: 0.000100
# Epoch 2/300 - Train loss: 3.5575 - Test loss: 3.3180 - Test accuracy: 0.1802 - LR: 0.000099
# Epoch 3/300 - Train loss: 3.0705 - Test loss: 2.8038 - Test accuracy: 0.3005 - LR: 0.000099
# Epoch 4/300 - Train loss: 2.5727 - Test loss: 2.3483 - Test accuracy: 0.4224 - LR: 0.000099
# Epoch 5/300 - Train loss: 2.1302 - Test loss: 1.9332 - Test accuracy: 0.5797 - LR: 0.000098
# Epoch 6/300 - Train loss: 1.7428 - Test loss: 1.5855 - Test accuracy: 0.6682 - LR: 0.000098
# Epoch 7/300 - Train loss: 1.4489 - Test loss: 1.3393 - Test accuracy: 0.7115 - LR: 0.000098
# Epoch 8/300 - Train loss: 1.2258 - Test loss: 1.1435 - Test accuracy: 0.7557 - LR: 0.000097
# Epoch 9/300 - Train loss: 1.0524 - Test loss: 1.0012 - Test accuracy: 0.7849 - LR: 0.000097
# Epoch 10/300 - Train loss: 0.9129 - Test loss: 0.8931 - Test accuracy: 0.8042 - LR: 0.000097
# Epoch 11/300 - Train loss: 0.8014 - Test loss: 0.8119 - Test accuracy: 0.8214 - LR: 0.000096
# Epoch 12/300 - Train loss: 0.7210 - Test loss: 0.7350 - Test accuracy: 0.8359 - LR: 0.000096
# Epoch 13/300 - Train loss: 0.6554 - Test loss: 0.6862 - Test accuracy: 0.8422 - LR: 0.000096
# Epoch 14/300 - Train loss: 0.5892 - Test loss: 0.6404 - Test accuracy: 0.8521 - LR: 0.000095
# Epoch 15/300 - Train loss: 0.5461 - Test loss: 0.5998 - Test accuracy: 0.8583 - LR: 0.000095
# Epoch 16/300 - Train loss: 0.4919 - Test loss: 0.5712 - Test accuracy: 0.8578 - LR: 0.000095
# Epoch 17/300 - Train loss: 0.4643 - Test loss: 0.5548 - Test accuracy: 0.8651 - LR: 0.000094
# Epoch 18/300 - Train loss: 0.4378 - Test loss: 0.5097 - Test accuracy: 0.8797 - LR: 0.000094
# Epoch 19/300 - Train loss: 0.3982 - Test loss: 0.4982 - Test accuracy: 0.8734 - LR: 0.000094
# Epoch 20/300 - Train loss: 0.3749 - Test loss: 0.4720 - Test accuracy: 0.8771 - LR: 0.000093
# Epoch 21/300 - Train loss: 0.3522 - Test loss: 0.4492 - Test accuracy: 0.8859 - LR: 0.000093
# Epoch 22/300 - Train loss: 0.3352 - Test loss: 0.4284 - Test accuracy: 0.8979 - LR: 0.000093
# Epoch 23/300 - Train loss: 0.3173 - Test loss: 0.4211 - Test accuracy: 0.8917 - LR: 0.000092
# Epoch 24/300 - Train loss: 0.2980 - Test loss: 0.4053 - Test accuracy: 0.8974 - LR: 0.000092
# Epoch 25/300 - Train loss: 0.2781 - Test loss: 0.3995 - Test accuracy: 0.8958 - LR: 0.000092
# Epoch 26/300 - Train loss: 0.2602 - Test loss: 0.3823 - Test accuracy: 0.9000 - LR: 0.000091
# Epoch 27/300 - Train loss: 0.2550 - Test loss: 0.3854 - Test accuracy: 0.8948 - LR: 0.000091
# Epoch 28/300 - Train loss: 0.2349 - Test loss: 0.3685 - Test accuracy: 0.9047 - LR: 0.000091
# Epoch 29/300 - Train loss: 0.2231 - Test loss: 0.3524 - Test accuracy: 0.9057 - LR: 0.000090
# Epoch 30/300 - Train loss: 0.2142 - Test loss: 0.3507 - Test accuracy: 0.9068 - LR: 0.000090
# Epoch 31/300 - Train loss: 0.2053 - Test loss: 0.3495 - Test accuracy: 0.9036 - LR: 0.000090
# Epoch 32/300 - Train loss: 0.1943 - Test loss: 0.3415 - Test accuracy: 0.9068 - LR: 0.000089
# Epoch 33/300 - Train loss: 0.1887 - Test loss: 0.3357 - Test accuracy: 0.9073 - LR: 0.000089
# Epoch 34/300 - Train loss: 0.1779 - Test loss: 0.3436 - Test accuracy: 0.9031 - LR: 0.000089
# Epoch 35/300 - Train loss: 0.1673 - Test loss: 0.3219 - Test accuracy: 0.9109 - LR: 0.000088
# Epoch 36/300 - Train loss: 0.1629 - Test loss: 0.3257 - Test accuracy: 0.9125 - LR: 0.000088
# Epoch 37/300 - Train loss: 0.1475 - Test loss: 0.3113 - Test accuracy: 0.9193 - LR: 0.000088
# Epoch 38/300 - Train loss: 0.1440 - Test loss: 0.3120 - Test accuracy: 0.9167 - LR: 0.000087
# Epoch 39/300 - Train loss: 0.1415 - Test loss: 0.3057 - Test accuracy: 0.9135 - LR: 0.000087
# Epoch 40/300 - Train loss: 0.1305 - Test loss: 0.2927 - Test accuracy: 0.9177 - LR: 0.000087
# Epoch 41/300 - Train loss: 0.1280 - Test loss: 0.2941 - Test accuracy: 0.9182 - LR: 0.000086
# Epoch 42/300 - Train loss: 0.1231 - Test loss: 0.3006 - Test accuracy: 0.9198 - LR: 0.000086
# Epoch 43/300 - Train loss: 0.1152 - Test loss: 0.2969 - Test accuracy: 0.9182 - LR: 0.000086
# Epoch 44/300 - Train loss: 0.1089 - Test loss: 0.2800 - Test accuracy: 0.9203 - LR: 0.000085
# Epoch 45/300 - Train loss: 0.1006 - Test loss: 0.2954 - Test accuracy: 0.9193 - LR: 0.000085
# Epoch 46/300 - Train loss: 0.1023 - Test loss: 0.2860 - Test accuracy: 0.9203 - LR: 0.000085
# Epoch 47/300 - Train loss: 0.0889 - Test loss: 0.2886 - Test accuracy: 0.9187 - LR: 0.000084
# Epoch 48/300 - Train loss: 0.0942 - Test loss: 0.2775 - Test accuracy: 0.9203 - LR: 0.000084
# Epoch 49/300 - Train loss: 0.0897 - Test loss: 0.2788 - Test accuracy: 0.9177 - LR: 0.000084
# Epoch 50/300 - Train loss: 0.0854 - Test loss: 0.2634 - Test accuracy: 0.9229 - LR: 0.000083
# Epoch 51/300 - Train loss: 0.0772 - Test loss: 0.2744 - Test accuracy: 0.9198 - LR: 0.000083
# Epoch 52/300 - Train loss: 0.0730 - Test loss: 0.2703 - Test accuracy: 0.9214 - LR: 0.000083
# Epoch 53/300 - Train loss: 0.0674 - Test loss: 0.2766 - Test accuracy: 0.9182 - LR: 0.000082
# Epoch 54/300 - Train loss: 0.0684 - Test loss: 0.2673 - Test accuracy: 0.9229 - LR: 0.000082
# Epoch 55/300 - Train loss: 0.0608 - Test loss: 0.2684 - Test accuracy: 0.9266 - LR: 0.000082
# Epoch 56/300 - Train loss: 0.0596 - Test loss: 0.2691 - Test accuracy: 0.9229 - LR: 0.000081
# Epoch 57/300 - Train loss: 0.0625 - Test loss: 0.2636 - Test accuracy: 0.9240 - LR: 0.000081
# Epoch 58/300 - Train loss: 0.0555 - Test loss: 0.2603 - Test accuracy: 0.9271 - LR: 0.000081
# Epoch 59/300 - Train loss: 0.0533 - Test loss: 0.2643 - Test accuracy: 0.9198 - LR: 0.000080
# Epoch 60/300 - Train loss: 0.0551 - Test loss: 0.2503 - Test accuracy: 0.9240 - LR: 0.000080
# Epoch 61/300 - Train loss: 0.0493 - Test loss: 0.2597 - Test accuracy: 0.9271 - LR: 0.000080
# Epoch 62/300 - Train loss: 0.0466 - Test loss: 0.2490 - Test accuracy: 0.9276 - LR: 0.000079
# Epoch 63/300 - Train loss: 0.0466 - Test loss: 0.2646 - Test accuracy: 0.9260 - LR: 0.000079
# Epoch 64/300 - Train loss: 0.0475 - Test loss: 0.2559 - Test accuracy: 0.9255 - LR: 0.000079
# Epoch 65/300 - Train loss: 0.0468 - Test loss: 0.2630 - Test accuracy: 0.9214 - LR: 0.000078
# Epoch 66/300 - Train loss: 0.0399 - Test loss: 0.2576 - Test accuracy: 0.9313 - LR: 0.000078
# Epoch 67/300 - Train loss: 0.0381 - Test loss: 0.2505 - Test accuracy: 0.9260 - LR: 0.000078
# Epoch 68/300 - Train loss: 0.0365 - Test loss: 0.2460 - Test accuracy: 0.9286 - LR: 0.000077
# Epoch 69/300 - Train loss: 0.0343 - Test loss: 0.2568 - Test accuracy: 0.9250 - LR: 0.000077
# Epoch 70/300 - Train loss: 0.0341 - Test loss: 0.2563 - Test accuracy: 0.9286 - LR: 0.000077
# Epoch 71/300 - Train loss: 0.0325 - Test loss: 0.2535 - Test accuracy: 0.9302 - LR: 0.000076
# Epoch 72/300 - Train loss: 0.0355 - Test loss: 0.2568 - Test accuracy: 0.9281 - LR: 0.000076
# Epoch 73/300 - Train loss: 0.0282 - Test loss: 0.2458 - Test accuracy: 0.9286 - LR: 0.000076
# Epoch 74/300 - Train loss: 0.0280 - Test loss: 0.2604 - Test accuracy: 0.9302 - LR: 0.000075
# Epoch 75/300 - Train loss: 0.0268 - Test loss: 0.2470 - Test accuracy: 0.9276 - LR: 0.000075
# Epoch 76/300 - Train loss: 0.0245 - Test loss: 0.2579 - Test accuracy: 0.9245 - LR: 0.000075
# Epoch 77/300 - Train loss: 0.0287 - Test loss: 0.2666 - Test accuracy: 0.9266 - LR: 0.000074
# Epoch 78/300 - Train loss: 0.0256 - Test loss: 0.2516 - Test accuracy: 0.9281 - LR: 0.000074
# Epoch 79/300 - Train loss: 0.0250 - Test loss: 0.2549 - Test accuracy: 0.9307 - LR: 0.000074
# Epoch 80/300 - Train loss: 0.0217 - Test loss: 0.2494 - Test accuracy: 0.9302 - LR: 0.000073
# Epoch 81/300 - Train loss: 0.0232 - Test loss: 0.2552 - Test accuracy: 0.9318 - LR: 0.000073
# Epoch 82/300 - Train loss: 0.0219 - Test loss: 0.2473 - Test accuracy: 0.9328 - LR: 0.000073
# Epoch 83/300 - Train loss: 0.0232 - Test loss: 0.2442 - Test accuracy: 0.9339 - LR: 0.000072
# Epoch 84/300 - Train loss: 0.0207 - Test loss: 0.2506 - Test accuracy: 0.9286 - LR: 0.000072
# Epoch 85/300 - Train loss: 0.0185 - Test loss: 0.2619 - Test accuracy: 0.9318 - LR: 0.000072
# Epoch 86/300 - Train loss: 0.0188 - Test loss: 0.2516 - Test accuracy: 0.9302 - LR: 0.000071
# Epoch 87/300 - Train loss: 0.0182 - Test loss: 0.2576 - Test accuracy: 0.9323 - LR: 0.000071
# Epoch 88/300 - Train loss: 0.0192 - Test loss: 0.2599 - Test accuracy: 0.9302 - LR: 0.000071
# Epoch 89/300 - Train loss: 0.0188 - Test loss: 0.2494 - Test accuracy: 0.9349 - LR: 0.000070
# Epoch 90/300 - Train loss: 0.0201 - Test loss: 0.2602 - Test accuracy: 0.9281 - LR: 0.000070
# Epoch 91/300 - Train loss: 0.0165 - Test loss: 0.2577 - Test accuracy: 0.9323 - LR: 0.000070
# Epoch 92/300 - Train loss: 0.0165 - Test loss: 0.2606 - Test accuracy: 0.9281 - LR: 0.000069
# Epoch 93/300 - Train loss: 0.0152 - Test loss: 0.2494 - Test accuracy: 0.9349 - LR: 0.000069
# Epoch 94/300 - Train loss: 0.0139 - Test loss: 0.2502 - Test accuracy: 0.9328 - LR: 0.000069
# Epoch 95/300 - Train loss: 0.0144 - Test loss: 0.2493 - Test accuracy: 0.9339 - LR: 0.000068
# Epoch 96/300 - Train loss: 0.0144 - Test loss: 0.2432 - Test accuracy: 0.9359 - LR: 0.000068
# Epoch 97/300 - Train loss: 0.0147 - Test loss: 0.2604 - Test accuracy: 0.9281 - LR: 0.000068
# Epoch 98/300 - Train loss: 0.0223 - Test loss: 0.2618 - Test accuracy: 0.9297 - LR: 0.000067
# Epoch 99/300 - Train loss: 0.0130 - Test loss: 0.2523 - Test accuracy: 0.9344 - LR: 0.000067
# Epoch 100/300 - Train loss: 0.0121 - Test loss: 0.2452 - Test accuracy: 0.9385 - LR: 0.000067
# Epoch 101/300 - Train loss: 0.0101 - Test loss: 0.2516 - Test accuracy: 0.9359 - LR: 0.000066
# Epoch 102/300 - Train loss: 0.0135 - Test loss: 0.2612 - Test accuracy: 0.9344 - LR: 0.000066
# Epoch 103/300 - Train loss: 0.0115 - Test loss: 0.2479 - Test accuracy: 0.9380 - LR: 0.000066
# Epoch 104/300 - Train loss: 0.0140 - Test loss: 0.2441 - Test accuracy: 0.9359 - LR: 0.000065
# Epoch 105/300 - Train loss: 0.0132 - Test loss: 0.2643 - Test accuracy: 0.9365 - LR: 0.000065
# Epoch 106/300 - Train loss: 0.0108 - Test loss: 0.2659 - Test accuracy: 0.9297 - LR: 0.000065
# Epoch 107/300 - Train loss: 0.0102 - Test loss: 0.2481 - Test accuracy: 0.9328 - LR: 0.000064
# Epoch 108/300 - Train loss: 0.0080 - Test loss: 0.2591 - Test accuracy: 0.9339 - LR: 0.000064
# Epoch 109/300 - Train loss: 0.0095 - Test loss: 0.2426 - Test accuracy: 0.9354 - LR: 0.000064
# Epoch 110/300 - Train loss: 0.0095 - Test loss: 0.2497 - Test accuracy: 0.9375 - LR: 0.000063
# Epoch 111/300 - Train loss: 0.0086 - Test loss: 0.2660 - Test accuracy: 0.9323 - LR: 0.000063
# Epoch 112/300 - Train loss: 0.0088 - Test loss: 0.2516 - Test accuracy: 0.9323 - LR: 0.000063
# Epoch 113/300 - Train loss: 0.0083 - Test loss: 0.2553 - Test accuracy: 0.9307 - LR: 0.000062
# Epoch 114/300 - Train loss: 0.0133 - Test loss: 0.2772 - Test accuracy: 0.9297 - LR: 0.000062
# Epoch 115/300 - Train loss: 0.0095 - Test loss: 0.2601 - Test accuracy: 0.9297 - LR: 0.000062
# Epoch 116/300 - Train loss: 0.0092 - Test loss: 0.2492 - Test accuracy: 0.9318 - LR: 0.000061
# Epoch 117/300 - Train loss: 0.0098 - Test loss: 0.2607 - Test accuracy: 0.9344 - LR: 0.000061
# Epoch 118/300 - Train loss: 0.0101 - Test loss: 0.2483 - Test accuracy: 0.9344 - LR: 0.000061
# Epoch 119/300 - Train loss: 0.0082 - Test loss: 0.2550 - Test accuracy: 0.9333 - LR: 0.000060
# Epoch 120/300 - Train loss: 0.0061 - Test loss: 0.2531 - Test accuracy: 0.9323 - LR: 0.000060
# Epoch 121/300 - Train loss: 0.0073 - Test loss: 0.2705 - Test accuracy: 0.9359 - LR: 0.000060
# Epoch 122/300 - Train loss: 0.0081 - Test loss: 0.2552 - Test accuracy: 0.9359 - LR: 0.000059
# Epoch 123/300 - Train loss: 0.0076 - Test loss: 0.2806 - Test accuracy: 0.9297 - LR: 0.000059
# Epoch 124/300 - Train loss: 0.0078 - Test loss: 0.2521 - Test accuracy: 0.9385 - LR: 0.000059
# Epoch 125/300 - Train loss: 0.0079 - Test loss: 0.2632 - Test accuracy: 0.9354 - LR: 0.000058
# Epoch 126/300 - Train loss: 0.0072 - Test loss: 0.2635 - Test accuracy: 0.9380 - LR: 0.000058
# Epoch 127/300 - Train loss: 0.0065 - Test loss: 0.2523 - Test accuracy: 0.9349 - LR: 0.000058
# Epoch 128/300 - Train loss: 0.0067 - Test loss: 0.2784 - Test accuracy: 0.9344 - LR: 0.000057
# Epoch 129/300 - Train loss: 0.0069 - Test loss: 0.2630 - Test accuracy: 0.9333 - LR: 0.000057
# Epoch 130/300 - Train loss: 0.0064 - Test loss: 0.2579 - Test accuracy: 0.9349 - LR: 0.000057
# Epoch 131/300 - Train loss: 0.0079 - Test loss: 0.2801 - Test accuracy: 0.9344 - LR: 0.000056
# Epoch 132/300 - Train loss: 0.0063 - Test loss: 0.2602 - Test accuracy: 0.9370 - LR: 0.000056
# Epoch 133/300 - Train loss: 0.0058 - Test loss: 0.2900 - Test accuracy: 0.9292 - LR: 0.000056
# Epoch 134/300 - Train loss: 0.0093 - Test loss: 0.2784 - Test accuracy: 0.9297 - LR: 0.000055
# Epoch 135/300 - Train loss: 0.0139 - Test loss: 0.2589 - Test accuracy: 0.9365 - LR: 0.000055
# Epoch 136/300 - Train loss: 0.0070 - Test loss: 0.2671 - Test accuracy: 0.9365 - LR: 0.000055
# Epoch 137/300 - Train loss: 0.0074 - Test loss: 0.2578 - Test accuracy: 0.9396 - LR: 0.000054
# Epoch 138/300 - Train loss: 0.0053 - Test loss: 0.2479 - Test accuracy: 0.9401 - LR: 0.000054
# Epoch 139/300 - Train loss: 0.0058 - Test loss: 0.2542 - Test accuracy: 0.9344 - LR: 0.000054
# Epoch 140/300 - Train loss: 0.0045 - Test loss: 0.2655 - Test accuracy: 0.9333 - LR: 0.000053
# Epoch 141/300 - Train loss: 0.0054 - Test loss: 0.2622 - Test accuracy: 0.9313 - LR: 0.000053
# Epoch 142/300 - Train loss: 0.0060 - Test loss: 0.2585 - Test accuracy: 0.9365 - LR: 0.000053
# Epoch 143/300 - Train loss: 0.0051 - Test loss: 0.2730 - Test accuracy: 0.9349 - LR: 0.000052
# Epoch 144/300 - Train loss: 0.0048 - Test loss: 0.2526 - Test accuracy: 0.9354 - LR: 0.000052
# Epoch 145/300 - Train loss: 0.0051 - Test loss: 0.2699 - Test accuracy: 0.9354 - LR: 0.000052
# Epoch 146/300 - Train loss: 0.0050 - Test loss: 0.2572 - Test accuracy: 0.9370 - LR: 0.000051
# Epoch 147/300 - Train loss: 0.0056 - Test loss: 0.2615 - Test accuracy: 0.9365 - LR: 0.000051
# Epoch 148/300 - Train loss: 0.0036 - Test loss: 0.2543 - Test accuracy: 0.9391 - LR: 0.000051
# Epoch 149/300 - Train loss: 0.0053 - Test loss: 0.2553 - Test accuracy: 0.9401 - LR: 0.000050
# Epoch 150/300 - Train loss: 0.0050 - Test loss: 0.2612 - Test accuracy: 0.9375 - LR: 0.000050
# Epoch 151/300 - Train loss: 0.0040 - Test loss: 0.2567 - Test accuracy: 0.9365 - LR: 0.000050
# Epoch 152/300 - Train loss: 0.0039 - Test loss: 0.2543 - Test accuracy: 0.9391 - LR: 0.000049
# Epoch 153/300 - Train loss: 0.0048 - Test loss: 0.2688 - Test accuracy: 0.9339 - LR: 0.000049
# Epoch 154/300 - Train loss: 0.0063 - Test loss: 0.2647 - Test accuracy: 0.9385 - LR: 0.000049
# Epoch 155/300 - Train loss: 0.0047 - Test loss: 0.2563 - Test accuracy: 0.9375 - LR: 0.000048
# Epoch 156/300 - Train loss: 0.0045 - Test loss: 0.2611 - Test accuracy: 0.9391 - LR: 0.000048
# Epoch 157/300 - Train loss: 0.0045 - Test loss: 0.2586 - Test accuracy: 0.9359 - LR: 0.000048
# Epoch 158/300 - Train loss: 0.0050 - Test loss: 0.2758 - Test accuracy: 0.9344 - LR: 0.000047
# Epoch 159/300 - Train loss: 0.0049 - Test loss: 0.2547 - Test accuracy: 0.9411 - LR: 0.000047
# Epoch 160/300 - Train loss: 0.0046 - Test loss: 0.2559 - Test accuracy: 0.9370 - LR: 0.000047
# Epoch 161/300 - Train loss: 0.0041 - Test loss: 0.2555 - Test accuracy: 0.9370 - LR: 0.000046
# Epoch 162/300 - Train loss: 0.0033 - Test loss: 0.2547 - Test accuracy: 0.9375 - LR: 0.000046
# Epoch 163/300 - Train loss: 0.0055 - Test loss: 0.2618 - Test accuracy: 0.9365 - LR: 0.000046
# Epoch 164/300 - Train loss: 0.0034 - Test loss: 0.2601 - Test accuracy: 0.9380 - LR: 0.000045
# Epoch 165/300 - Train loss: 0.0042 - Test loss: 0.2616 - Test accuracy: 0.9411 - LR: 0.000045
# Epoch 166/300 - Train loss: 0.0028 - Test loss: 0.2549 - Test accuracy: 0.9427 - LR: 0.000045
# Epoch 167/300 - Train loss: 0.0039 - Test loss: 0.2565 - Test accuracy: 0.9406 - LR: 0.000044
# Epoch 168/300 - Train loss: 0.0039 - Test loss: 0.2594 - Test accuracy: 0.9391 - LR: 0.000044
# Epoch 169/300 - Train loss: 0.0034 - Test loss: 0.2693 - Test accuracy: 0.9380 - LR: 0.000044
# Epoch 170/300 - Train loss: 0.0034 - Test loss: 0.2633 - Test accuracy: 0.9432 - LR: 0.000043
# Epoch 171/300 - Train loss: 0.0034 - Test loss: 0.2672 - Test accuracy: 0.9385 - LR: 0.000043
# Epoch 172/300 - Train loss: 0.0037 - Test loss: 0.2680 - Test accuracy: 0.9417 - LR: 0.000043
# Epoch 173/300 - Train loss: 0.0043 - Test loss: 0.2616 - Test accuracy: 0.9375 - LR: 0.000042
# Epoch 174/300 - Train loss: 0.0030 - Test loss: 0.2517 - Test accuracy: 0.9406 - LR: 0.000042
# Epoch 175/300 - Train loss: 0.0033 - Test loss: 0.2634 - Test accuracy: 0.9396 - LR: 0.000042
# Epoch 176/300 - Train loss: 0.0032 - Test loss: 0.2521 - Test accuracy: 0.9406 - LR: 0.000041
# Epoch 177/300 - Train loss: 0.0041 - Test loss: 0.2704 - Test accuracy: 0.9344 - LR: 0.000041
# Epoch 178/300 - Train loss: 0.0033 - Test loss: 0.2542 - Test accuracy: 0.9396 - LR: 0.000041
# Epoch 179/300 - Train loss: 0.0033 - Test loss: 0.2544 - Test accuracy: 0.9396 - LR: 0.000040
# Epoch 180/300 - Train loss: 0.0030 - Test loss: 0.2561 - Test accuracy: 0.9385 - LR: 0.000040
# Epoch 181/300 - Train loss: 0.0042 - Test loss: 0.2599 - Test accuracy: 0.9385 - LR: 0.000040
# Epoch 182/300 - Train loss: 0.0034 - Test loss: 0.2521 - Test accuracy: 0.9411 - LR: 0.000039
# Epoch 183/300 - Train loss: 0.0029 - Test loss: 0.2449 - Test accuracy: 0.9417 - LR: 0.000039
# Epoch 184/300 - Train loss: 0.0026 - Test loss: 0.2436 - Test accuracy: 0.9427 - LR: 0.000039
# Epoch 185/300 - Train loss: 0.0023 - Test loss: 0.2640 - Test accuracy: 0.9411 - LR: 0.000038
# Epoch 186/300 - Train loss: 0.0022 - Test loss: 0.2521 - Test accuracy: 0.9385 - LR: 0.000038
# Epoch 187/300 - Train loss: 0.0024 - Test loss: 0.2601 - Test accuracy: 0.9396 - LR: 0.000038
# Epoch 188/300 - Train loss: 0.0040 - Test loss: 0.2542 - Test accuracy: 0.9411 - LR: 0.000037
# Epoch 189/300 - Train loss: 0.0039 - Test loss: 0.2743 - Test accuracy: 0.9411 - LR: 0.000037
# Epoch 190/300 - Train loss: 0.0037 - Test loss: 0.2511 - Test accuracy: 0.9375 - LR: 0.000037
# Epoch 191/300 - Train loss: 0.0036 - Test loss: 0.2649 - Test accuracy: 0.9417 - LR: 0.000036
# Epoch 192/300 - Train loss: 0.0029 - Test loss: 0.2519 - Test accuracy: 0.9380 - LR: 0.000036
# Epoch 193/300 - Train loss: 0.0023 - Test loss: 0.2583 - Test accuracy: 0.9375 - LR: 0.000036
# Epoch 194/300 - Train loss: 0.0030 - Test loss: 0.2626 - Test accuracy: 0.9380 - LR: 0.000035
# Epoch 195/300 - Train loss: 0.0024 - Test loss: 0.2686 - Test accuracy: 0.9370 - LR: 0.000035
# Epoch 196/300 - Train loss: 0.0026 - Test loss: 0.2719 - Test accuracy: 0.9396 - LR: 0.000035
# Epoch 197/300 - Train loss: 0.0021 - Test loss: 0.2625 - Test accuracy: 0.9411 - LR: 0.000034
# Epoch 198/300 - Train loss: 0.0019 - Test loss: 0.2548 - Test accuracy: 0.9396 - LR: 0.000034
# Epoch 199/300 - Train loss: 0.0022 - Test loss: 0.2611 - Test accuracy: 0.9375 - LR: 0.000034
# Epoch 200/300 - Train loss: 0.0025 - Test loss: 0.2647 - Test accuracy: 0.9417 - LR: 0.000033
# Epoch 201/300 - Train loss: 0.0029 - Test loss: 0.2681 - Test accuracy: 0.9365 - LR: 0.000033
# Epoch 202/300 - Train loss: 0.0033 - Test loss: 0.2638 - Test accuracy: 0.9401 - LR: 0.000033
# Epoch 203/300 - Train loss: 0.0031 - Test loss: 0.2677 - Test accuracy: 0.9427 - LR: 0.000032
# Epoch 204/300 - Train loss: 0.0022 - Test loss: 0.2650 - Test accuracy: 0.9380 - LR: 0.000032
# Epoch 205/300 - Train loss: 0.0023 - Test loss: 0.2644 - Test accuracy: 0.9396 - LR: 0.000032
# Epoch 206/300 - Train loss: 0.0022 - Test loss: 0.2595 - Test accuracy: 0.9422 - LR: 0.000031
# Epoch 207/300 - Train loss: 0.0018 - Test loss: 0.2600 - Test accuracy: 0.9411 - LR: 0.000031
# Epoch 208/300 - Train loss: 0.0025 - Test loss: 0.2632 - Test accuracy: 0.9375 - LR: 0.000031
# Epoch 209/300 - Train loss: 0.0019 - Test loss: 0.2669 - Test accuracy: 0.9406 - LR: 0.000030
# Epoch 210/300 - Train loss: 0.0018 - Test loss: 0.2605 - Test accuracy: 0.9427 - LR: 0.000030
# Epoch 211/300 - Train loss: 0.0017 - Test loss: 0.2631 - Test accuracy: 0.9427 - LR: 0.000030
# Epoch 212/300 - Train loss: 0.0015 - Test loss: 0.2643 - Test accuracy: 0.9406 - LR: 0.000029
# Epoch 213/300 - Train loss: 0.0016 - Test loss: 0.2598 - Test accuracy: 0.9432 - LR: 0.000029
# Epoch 214/300 - Train loss: 0.0021 - Test loss: 0.2666 - Test accuracy: 0.9396 - LR: 0.000029
# Epoch 215/300 - Train loss: 0.0016 - Test loss: 0.2667 - Test accuracy: 0.9391 - LR: 0.000028
# Epoch 216/300 - Train loss: 0.0026 - Test loss: 0.2715 - Test accuracy: 0.9411 - LR: 0.000028
# Epoch 217/300 - Train loss: 0.0022 - Test loss: 0.2637 - Test accuracy: 0.9391 - LR: 0.000028
# Epoch 218/300 - Train loss: 0.0045 - Test loss: 0.2864 - Test accuracy: 0.9365 - LR: 0.000027
# Epoch 219/300 - Train loss: 0.0018 - Test loss: 0.2648 - Test accuracy: 0.9375 - LR: 0.000027
# Epoch 220/300 - Train loss: 0.0019 - Test loss: 0.2649 - Test accuracy: 0.9411 - LR: 0.000027
# Epoch 221/300 - Train loss: 0.0023 - Test loss: 0.2635 - Test accuracy: 0.9380 - LR: 0.000026
# Epoch 222/300 - Train loss: 0.0018 - Test loss: 0.2621 - Test accuracy: 0.9411 - LR: 0.000026
# Epoch 223/300 - Train loss: 0.0033 - Test loss: 0.2612 - Test accuracy: 0.9406 - LR: 0.000026
# Epoch 224/300 - Train loss: 0.0017 - Test loss: 0.2603 - Test accuracy: 0.9401 - LR: 0.000025
# Epoch 225/300 - Train loss: 0.0022 - Test loss: 0.2632 - Test accuracy: 0.9391 - LR: 0.000025
# Epoch 226/300 - Train loss: 0.0020 - Test loss: 0.2761 - Test accuracy: 0.9391 - LR: 0.000025
# Epoch 227/300 - Train loss: 0.0022 - Test loss: 0.2730 - Test accuracy: 0.9406 - LR: 0.000024
# Epoch 228/300 - Train loss: 0.0014 - Test loss: 0.2648 - Test accuracy: 0.9427 - LR: 0.000024
# Epoch 229/300 - Train loss: 0.0017 - Test loss: 0.2653 - Test accuracy: 0.9391 - LR: 0.000024
# Epoch 230/300 - Train loss: 0.0020 - Test loss: 0.2708 - Test accuracy: 0.9417 - LR: 0.000023
# Epoch 231/300 - Train loss: 0.0021 - Test loss: 0.2595 - Test accuracy: 0.9411 - LR: 0.000023
# Epoch 232/300 - Train loss: 0.0017 - Test loss: 0.2611 - Test accuracy: 0.9401 - LR: 0.000023
# Epoch 233/300 - Train loss: 0.0017 - Test loss: 0.2705 - Test accuracy: 0.9391 - LR: 0.000022
# Epoch 234/300 - Train loss: 0.0020 - Test loss: 0.2546 - Test accuracy: 0.9406 - LR: 0.000022
# Epoch 235/300 - Train loss: 0.0016 - Test loss: 0.2676 - Test accuracy: 0.9391 - LR: 0.000022
# Epoch 236/300 - Train loss: 0.0026 - Test loss: 0.2658 - Test accuracy: 0.9432 - LR: 0.000021
# Epoch 237/300 - Train loss: 0.0019 - Test loss: 0.2569 - Test accuracy: 0.9437 - LR: 0.000021
# Epoch 238/300 - Train loss: 0.0015 - Test loss: 0.2504 - Test accuracy: 0.9422 - LR: 0.000021
# Epoch 239/300 - Train loss: 0.0018 - Test loss: 0.2650 - Test accuracy: 0.9401 - LR: 0.000020
# Epoch 240/300 - Train loss: 0.0012 - Test loss: 0.2612 - Test accuracy: 0.9417 - LR: 0.000020
# Epoch 241/300 - Train loss: 0.0011 - Test loss: 0.2587 - Test accuracy: 0.9422 - LR: 0.000020
# Epoch 242/300 - Train loss: 0.0015 - Test loss: 0.2622 - Test accuracy: 0.9422 - LR: 0.000019
# Epoch 243/300 - Train loss: 0.0015 - Test loss: 0.2630 - Test accuracy: 0.9385 - LR: 0.000019
# Epoch 244/300 - Train loss: 0.0016 - Test loss: 0.2642 - Test accuracy: 0.9380 - LR: 0.000019
# Epoch 245/300 - Train loss: 0.0015 - Test loss: 0.2611 - Test accuracy: 0.9432 - LR: 0.000018
# Epoch 246/300 - Train loss: 0.0015 - Test loss: 0.2586 - Test accuracy: 0.9432 - LR: 0.000018
# Epoch 247/300 - Train loss: 0.0016 - Test loss: 0.2627 - Test accuracy: 0.9417 - LR: 0.000018
# Epoch 248/300 - Train loss: 0.0013 - Test loss: 0.2563 - Test accuracy: 0.9422 - LR: 0.000017
# Epoch 249/300 - Train loss: 0.0014 - Test loss: 0.2673 - Test accuracy: 0.9432 - LR: 0.000017
# Epoch 250/300 - Train loss: 0.0018 - Test loss: 0.2602 - Test accuracy: 0.9422 - LR: 0.000017
# Epoch 251/300 - Train loss: 0.0014 - Test loss: 0.2612 - Test accuracy: 0.9427 - LR: 0.000016
# Epoch 252/300 - Train loss: 0.0012 - Test loss: 0.2657 - Test accuracy: 0.9396 - LR: 0.000016
# Epoch 253/300 - Train loss: 0.0014 - Test loss: 0.2508 - Test accuracy: 0.9443 - LR: 0.000016
# Epoch 254/300 - Train loss: 0.0014 - Test loss: 0.2549 - Test accuracy: 0.9411 - LR: 0.000015
# Epoch 255/300 - Train loss: 0.0028 - Test loss: 0.2652 - Test accuracy: 0.9411 - LR: 0.000015
# Epoch 256/300 - Train loss: 0.0014 - Test loss: 0.2718 - Test accuracy: 0.9417 - LR: 0.000015
# Epoch 257/300 - Train loss: 0.0018 - Test loss: 0.2708 - Test accuracy: 0.9396 - LR: 0.000014
# Epoch 258/300 - Train loss: 0.0011 - Test loss: 0.2637 - Test accuracy: 0.9385 - LR: 0.000014
# Epoch 259/300 - Train loss: 0.0023 - Test loss: 0.2638 - Test accuracy: 0.9427 - LR: 0.000014
# Epoch 260/300 - Train loss: 0.0028 - Test loss: 0.2579 - Test accuracy: 0.9427 - LR: 0.000013
# Epoch 261/300 - Train loss: 0.0012 - Test loss: 0.2644 - Test accuracy: 0.9437 - LR: 0.000013
# Epoch 262/300 - Train loss: 0.0021 - Test loss: 0.2620 - Test accuracy: 0.9427 - LR: 0.000013
# Epoch 263/300 - Train loss: 0.0014 - Test loss: 0.2612 - Test accuracy: 0.9411 - LR: 0.000012
# Epoch 264/300 - Train loss: 0.0012 - Test loss: 0.2613 - Test accuracy: 0.9422 - LR: 0.000012
# Epoch 265/300 - Train loss: 0.0010 - Test loss: 0.2672 - Test accuracy: 0.9401 - LR: 0.000012
# Epoch 266/300 - Train loss: 0.0014 - Test loss: 0.2673 - Test accuracy: 0.9406 - LR: 0.000011
# Epoch 267/300 - Train loss: 0.0021 - Test loss: 0.2622 - Test accuracy: 0.9437 - LR: 0.000011
# Epoch 268/300 - Train loss: 0.0017 - Test loss: 0.2672 - Test accuracy: 0.9417 - LR: 0.000011
# Epoch 269/300 - Train loss: 0.0011 - Test loss: 0.2663 - Test accuracy: 0.9422 - LR: 0.000010
# Epoch 270/300 - Train loss: 0.0012 - Test loss: 0.2662 - Test accuracy: 0.9406 - LR: 0.000010
# Epoch 271/300 - Train loss: 0.0010 - Test loss: 0.2644 - Test accuracy: 0.9422 - LR: 0.000010
# Epoch 272/300 - Train loss: 0.0010 - Test loss: 0.2603 - Test accuracy: 0.9417 - LR: 0.000009
# Epoch 273/300 - Train loss: 0.0014 - Test loss: 0.2634 - Test accuracy: 0.9401 - LR: 0.000009
# Epoch 274/300 - Train loss: 0.0012 - Test loss: 0.2618 - Test accuracy: 0.9401 - LR: 0.000009
# Epoch 275/300 - Train loss: 0.0011 - Test loss: 0.2633 - Test accuracy: 0.9401 - LR: 0.000008
# Epoch 276/300 - Train loss: 0.0011 - Test loss: 0.2634 - Test accuracy: 0.9385 - LR: 0.000008
# Epoch 277/300 - Train loss: 0.0011 - Test loss: 0.2635 - Test accuracy: 0.9437 - LR: 0.000008
# Epoch 278/300 - Train loss: 0.0011 - Test loss: 0.2625 - Test accuracy: 0.9427 - LR: 0.000007
# Epoch 279/300 - Train loss: 0.0009 - Test loss: 0.2625 - Test accuracy: 0.9406 - LR: 0.000007
# Epoch 280/300 - Train loss: 0.0009 - Test loss: 0.2643 - Test accuracy: 0.9417 - LR: 0.000007
# Epoch 281/300 - Train loss: 0.0011 - Test loss: 0.2617 - Test accuracy: 0.9427 - LR: 0.000006
# Epoch 282/300 - Train loss: 0.0016 - Test loss: 0.2673 - Test accuracy: 0.9411 - LR: 0.000006
# Epoch 283/300 - Train loss: 0.0011 - Test loss: 0.2618 - Test accuracy: 0.9422 - LR: 0.000006
# Epoch 284/300 - Train loss: 0.0010 - Test loss: 0.2630 - Test accuracy: 0.9411 - LR: 0.000005
# Epoch 285/300 - Train loss: 0.0011 - Test loss: 0.2577 - Test accuracy: 0.9396 - LR: 0.000005
# Epoch 286/300 - Train loss: 0.0011 - Test loss: 0.2614 - Test accuracy: 0.9458 - LR: 0.000005
# Epoch 287/300 - Train loss: 0.0010 - Test loss: 0.2598 - Test accuracy: 0.9427 - LR: 0.000004
# Epoch 288/300 - Train loss: 0.0009 - Test loss: 0.2555 - Test accuracy: 0.9427 - LR: 0.000004
# Epoch 289/300 - Train loss: 0.0009 - Test loss: 0.2631 - Test accuracy: 0.9417 - LR: 0.000004
# Epoch 290/300 - Train loss: 0.0012 - Test loss: 0.2607 - Test accuracy: 0.9437 - LR: 0.000003
# Epoch 291/300 - Train loss: 0.0007 - Test loss: 0.2602 - Test accuracy: 0.9432 - LR: 0.000003
# Epoch 292/300 - Train loss: 0.0008 - Test loss: 0.2621 - Test accuracy: 0.9417 - LR: 0.000003
# Epoch 293/300 - Train loss: 0.0013 - Test loss: 0.2636 - Test accuracy: 0.9411 - LR: 0.000002
# Epoch 294/300 - Train loss: 0.0012 - Test loss: 0.2618 - Test accuracy: 0.9432 - LR: 0.000002
# Epoch 295/300 - Train loss: 0.0011 - Test loss: 0.2593 - Test accuracy: 0.9417 - LR: 0.000002
# Epoch 296/300 - Train loss: 0.0011 - Test loss: 0.2589 - Test accuracy: 0.9432 - LR: 0.000001
# Epoch 297/300 - Train loss: 0.0009 - Test loss: 0.2658 - Test accuracy: 0.9401 - LR: 0.000001
# Epoch 298/300 - Train loss: 0.0010 - Test loss: 0.2595 - Test accuracy: 0.9422 - LR: 0.000001
# Epoch 299/300 - Train loss: 0.0007 - Test loss: 0.2583 - Test accuracy: 0.9427 - LR: 0.000000
# Epoch 300/300 - Train loss: 0.0013 - Test loss: 0.2596 - Test accuracy: 0.9432 - LR: 0.000000
# Saving best model at epoch 109 and test loss 0.2426
# Best epoch: 109 - Test loss: 0.2426 - Test accuracy: 0.9354

# %% [markdown]
# ## Siamese Networks

# %%
import pickle
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torch.optim.lr_scheduler import LambdaLR
import matplotlib.pyplot as plt
import os

seed = 2710
np.random.seed(seed)
torch.manual_seed(seed)

class MultiBranchSiameseNet(nn.Module):
    def __init__(self, num_channels=3, num_classes=5, num_timesteps=128):
        super(MultiBranchSiameseNet, self).__init__()
        # Shared layers
        self.conv1 = nn.Conv1d(num_channels, 16, kernel_size=5, stride=1, padding=2)
        self.bn1 = nn.BatchNorm1d(16)
        self.conv2 = nn.Conv1d(16, 32, kernel_size=5, stride=1, padding=2)
        self.bn2 = nn.BatchNorm1d(32)
        self.conv3 = nn.Conv1d(32, 64, kernel_size=5, stride=1, padding=2)
        self.bn3 = nn.BatchNorm1d(64)
        self.conv4 = nn.Conv1d(64, 128, kernel_size=5, stride=1, padding=2)
        self.bn4 = nn.BatchNorm1d(128)
        self.pool = nn.MaxPool1d(kernel_size=2, stride=2)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.25)
        self.fc_shared = nn.Linear(num_timesteps * 8, 100)

        # Class-specific branches
        self.fc_class_branches = nn.Linear(100, 50 * num_classes)

    def forward_once(self, x, class_id):
        x = self.pool(self.relu(self.bn1(self.conv1(x))))
        x = self.pool(self.relu(self.bn2(self.conv2(x))))
        x = self.pool(self.relu(self.bn3(self.conv3(x))))
        x = self.pool(self.relu(self.bn4(self.conv4(x))))
        x = x.view(x.size(0), -1)
        x = self.dropout(x)
        x = self.relu(self.fc_shared(x))

        # Process class-specific branch
        class_branches = self.fc_class_branches(x).view(x.size(0), -1, 50)
        class_output = class_branches[torch.arange(class_branches.size(0)), class_id]
        return class_output


def split_data(x, y, k, test_size=0.2, random_state=seed):
    x_train, x_test, y_train, y_test, k_train, k_test = train_test_split(x, y, k,
                                                                         test_size=test_size,
                                                                         random_state=random_state,
                                                                         stratify=k,
                                                                         shuffle=True)
    return x_train, x_test, y_train, y_test, k_train, k_test


def setup_training(x_train, y_train, k_train, x_test, y_test, k_test, batch_size=64):
    # Convert numpy arrays to torch tensors
    x_train_tensor = torch.tensor(x_train, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train, dtype=torch.long)
    k_train_tensor = torch.tensor(k_train, dtype=torch.long)
    x_test_tensor = torch.tensor(x_test, dtype=torch.float32)
    y_test_tensor = torch.tensor(y_test, dtype=torch.long)
    k_test_tensor = torch.tensor(k_test, dtype=torch.long)

    # Create datasets and loaders
    train_dataset = TensorDataset(x_train_tensor, y_train_tensor, k_train_tensor)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_dataset = TensorDataset(x_test_tensor, y_test_tensor, k_test_tensor)
    test_loader = DataLoader(test_dataset, batch_size=batch_size)

    return train_loader, test_loader


def evaluate_model(model, test_loader, device='cpu', margin=1.0):
    model.eval()
    total_loss = 0
    same_domain_distance = 0
    diff_domain_distance = 0
    same_domain_count = 0
    diff_domain_count = 0

    with torch.no_grad():
        for x_batch, y_batch, k_batch in test_loader:
            x_batch, y_batch, k_batch = x_batch.to(device), y_batch.to(device), k_batch.to(device)
            batch_size = x_batch.size(0)

            # Compute all pairwise outputs
            output1 = model.forward_once(x_batch.unsqueeze(1).expand(-1, batch_size, -1, -1).reshape(-1, x_batch.size(1), x_batch.size(2)),
                                         y_batch.unsqueeze(1).expand(-1, batch_size).reshape(-1))
            output2 = model.forward_once(x_batch.unsqueeze(0).expand(batch_size, -1, -1, -1).reshape(-1, x_batch.size(1), x_batch.size(2)),
                                         y_batch.unsqueeze(0).expand(batch_size, -1).reshape(-1))

            output1 = output1.view(batch_size, batch_size, -1)
            output2 = output2.view(batch_size, batch_size, -1)

            # Compute pairwise distances
            euclidean_distances = F.pairwise_distance(output1, output2, keepdim=True).view(batch_size, batch_size)

            # Compute pairwise labels
            labels = (k_batch.unsqueeze(1) != k_batch.unsqueeze(0)).float()

            # Compute loss
            loss = (1 - labels) * torch.pow(euclidean_distances, 2) + labels * torch.pow(torch.clamp(margin - euclidean_distances, min=0.0), 2)
            total_loss += loss.mean().item()

            # Compute distances for same and different domains
            same_domain_distance += euclidean_distances[labels == 0].sum().item()
            diff_domain_distance += euclidean_distances[labels == 1].sum().item()
            same_domain_count += (labels == 0).sum().item()
            diff_domain_count += (labels == 1).sum().item()

    total_loss /= len(test_loader)
    avg_same_domain_distance = same_domain_distance / same_domain_count if same_domain_count > 0 else 0
    avg_diff_domain_distance = diff_domain_distance / diff_domain_count if diff_domain_count > 0 else 0

    return total_loss, avg_same_domain_distance, avg_diff_domain_distance


def train_model(model, train_loader, test_loader, optimizer, epochs=300, name='siamese_net', margin=1.0):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    loss_train = []
    loss_test = []
    avg_same_domain_distance_test = []
    avg_diff_domain_distance_test = []
    best_loss = np.inf

    # Set up linear learning rate decay
    lambda_lr = lambda epoch: 1 - epoch / epochs
    scheduler = LambdaLR(optimizer, lr_lambda=lambda_lr)

    for epoch in range(epochs):
        model.train()
        total_loss = 0
        for x_batch, y_batch, k_batch in train_loader:
            x_batch, y_batch, k_batch = x_batch.to(device), y_batch.to(device), k_batch.to(device)
            batch_size = x_batch.size(0)

            # Compute all pairwise outputs
            output1 = model.forward_once(x_batch.unsqueeze(1).expand(-1, batch_size, -1, -1).reshape(-1, x_batch.size(1), x_batch.size(2)),
                                         y_batch.unsqueeze(1).expand(-1, batch_size).reshape(-1))
            output2 = model.forward_once(x_batch.unsqueeze(0).expand(batch_size, -1, -1, -1).reshape(-1, x_batch.size(1), x_batch.size(2)),
                                         y_batch.unsqueeze(0).expand(batch_size, -1).reshape(-1))

            output1 = output1.view(batch_size, batch_size, -1)
            output2 = output2.view(batch_size, batch_size, -1)

            # Compute pairwise distances
            euclidean_distances = F.pairwise_distance(output1, output2, keepdim=True).view(batch_size, batch_size)

            # Compute pairwise labels
            labels = (k_batch.unsqueeze(1) != k_batch.unsqueeze(0)).float()

            # Compute loss
            loss = (1 - labels) * torch.pow(euclidean_distances, 2) + labels * torch.pow(torch.clamp(margin - euclidean_distances, min=0.0), 2)
            total_loss += loss.mean().item()

            optimizer.zero_grad()
            loss.mean().backward()
            optimizer.step()

        total_loss /= len(train_loader)
        loss_train.append(total_loss)

        # Update learning rate
        scheduler.step()

        test_loss, avg_same_domain_distance, avg_diff_domain_distance = evaluate_model(model, test_loader, device=device)
        if test_loss < best_loss:
            best_loss = test_loss
            best_model = model.state_dict().copy()
        loss_test.append(test_loss)
        avg_same_domain_distance_test.append(avg_same_domain_distance)
        avg_diff_domain_distance_test.append(avg_diff_domain_distance)

        current_lr = scheduler.get_last_lr()[0]
        print(f"Epoch {epoch + 1}/{epochs} - Train loss: {total_loss:.4f} - Test loss: {test_loss:.4f} - "
              f"Avg same domain distance: {avg_same_domain_distance:.4f} - Avg diff domain distance: {avg_diff_domain_distance:.4f} - LR: {current_lr:.6f}")

    # Save best model
    os.makedirs('pretrained_nets', exist_ok=True)
    if best_model is not None:
        print(f"Saving best model at epoch {np.argmin(loss_test) + 1} and test loss {best_loss:.4f}")
        torch.save(best_model, f"pretrained_nets/{name}.ckpt")
    else:
        print("No best model found, saving current model")
        torch.save(model.state_dict(), f"pretrained_nets/{name}.ckpt")

    return loss_train, loss_test, avg_same_domain_distance_test, avg_diff_domain_distance_test

# %%
# Train Siamese network on Df

if dataset == 'realworld':
    dataset_name = 'realworld_128_3ch_4cl'
    num_df_domains = 10
    num_dp_domains = 5
    num_classes = 4

elif dataset == 'cwru':
    dataset_name = 'cwru_256_3ch_5cl'
    num_df_domains = 4
    num_dp_domains = 4
    num_classes = 5

elif dataset == 'realworld_mobiact':
    dataset_name = 'realworld_mobiact'
    num_df_domains = 15
    num_dp_domains = 61
    num_classes = 4


with open(f'data/{dataset_name}.pkl', 'rb') as f:
    x, y, k = pickle.load(f)

x = x[k < num_df_domains]
y = y[k < num_df_domains]
k = k[k < num_df_domains]
print(x.shape, y.shape, k.shape)

x_train, x_test, y_train, y_test, k_train, k_test = split_data(x, y, k, test_size=0.2, random_state=seed)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape, k_train.shape, k_test.shape)

model = MultiBranchSiameseNet(num_classes=num_classes, num_timesteps=x_train.shape[2])

train_loader, test_loader = setup_training(x_train, y_train, k_train, x_test, y_test, k_test)

initial_lr = 0.0001
optimizer = optim.Adam(model.parameters(), lr=initial_lr)

loss_train, loss_test, avg_same_domain_distance_test, avg_diff_domain_distance_test = train_model(model, train_loader, test_loader, optimizer, epochs=200, name=f'siamese_net_{dataset}_df')

# Find the best epoch based on the test loss
best_epoch = np.argmin(loss_test)
print(f"Best epoch: {best_epoch + 1} - Test loss: {loss_test[best_epoch]:.4f} - Avg same domain distance: {avg_same_domain_distance_test[best_epoch]:.4f} - Avg diff domain distance: {avg_diff_domain_distance_test[best_epoch]:.4f}")

# Plot the training and test loss displaying the best epoch with a vertical line
plt.figure(figsize=(15, 6))
plt.plot(loss_train, label='Train loss')
plt.plot(loss_test, label='Test loss')
plt.axvline(best_epoch, color='r', linestyle='--')
plt.yscale('log')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# Plot the average same domain distance
plt.figure(figsize=(15, 6))
plt.plot(avg_same_domain_distance_test, label='Avg same domain distance')
plt.axvline(best_epoch, color='r', linestyle='--')
plt.xlabel('Epoch')
plt.ylabel('Avg Same Domain Distance')
plt.legend()
plt.grid()
plt.show()

# Plot the average different domain distance
plt.figure(figsize=(15, 6))
plt.plot(avg_diff_domain_distance_test, label='Avg diff domain distance')
plt.axvline(best_epoch, color='r', linestyle='--')
plt.xlabel('Epoch')
plt.ylabel('Avg Diff Domain Distance')
plt.legend()
plt.grid()
plt.show()

# %%
# Train Siamese Network on Dp

with open(f'data/{dataset_name}.pkl', 'rb') as f:
    x, y, k = pickle.load(f)

with open(f'data/{dataset_name}_fs.pkl', 'rb') as f:
    fs = pickle.load(f)

x = x[fs == 0]
y = y[fs == 0]
k = k[fs == 0]
x = x[k >= num_df_domains]
y = y[k >= num_df_domains]
k = k[k >= num_df_domains] - num_df_domains
print(x.shape, y.shape, k.shape)

x_train, x_test, y_train, y_test, k_train, k_test = split_data(x, y, k, test_size=0.2, random_state=seed)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape, k_train.shape, k_test.shape)

model = MultiBranchSiameseNet(num_classes=num_classes, num_timesteps=x_train.shape[2])

train_loader, test_loader = setup_training(x_train, y_train, k_train, x_test, y_test, k_test)

initial_lr = 0.0001
optimizer = optim.Adam(model.parameters(), lr=initial_lr)

loss_train, loss_test, avg_same_domain_distance_test, avg_diff_domain_distance_test = train_model(model, train_loader, test_loader, optimizer, epochs=200, name=f'siamese_net_{dataset}_dp')

# Find the best epoch based on the test loss
best_epoch = np.argmin(loss_test)
print(f"Best epoch: {best_epoch + 1} - Test loss: {loss_test[best_epoch]:.4f} - Avg same domain distance: {avg_same_domain_distance_test[best_epoch]:.4f} - Avg diff domain distance: {avg_diff_domain_distance_test[best_epoch]:.4f}")

# Plot the training and test loss displaying the best epoch with a vertical line
plt.figure(figsize=(15, 6))
plt.plot(loss_train, label='Train loss')
plt.plot(loss_test, label='Test loss')
plt.axvline(best_epoch, color='r', linestyle='--')
plt.yscale('log')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# Plot the average same domain distance
plt.figure(figsize=(15, 6))
plt.plot(avg_same_domain_distance_test, label='Avg same domain distance')
plt.axvline(best_epoch, color='r', linestyle='--')
plt.xlabel('Epoch')
plt.ylabel('Avg Same Domain Distance')
plt.legend()
plt.grid()
plt.show()

# Plot the average different domain distance
plt.figure(figsize=(15, 6))
plt.plot(avg_diff_domain_distance_test, label='Avg diff domain distance')
plt.axvline(best_epoch, color='r', linestyle='--')
plt.xlabel('Epoch')
plt.ylabel('Avg Diff Domain Distance')
plt.legend()
plt.grid()
plt.show()
